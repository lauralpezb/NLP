# %% [markdown]
# # Recomendador de películas basado en contenido
#
# ## Laura Cristina López Bedoya
#
# En esta práctica vamos a aplicar algunos de los conceptos que hemos desarrollado a lo largo de las clases de este módulo. Vamos a construir un recomendador de películas basado en contenido pero que se apoye en herramientas de procesamiento de lenguaje natural para modelar ese contenido. Utilizaremos un conjunto de datos descargado de IMDB, la base de datos de películas de internet, lo preprocesaremos para extraer la información que más nos interese y llevaremos a cabo recomendaciones basadas en la misma. Posteriormente, como gran cantidad de la información de la película la tenemos en un campo de texto libre probaremos distintas aproximaciones basadas en procesamiento de lenguaje natural.
#
# Toda la tarea se desarrollará en este Jupyter Notebook siguiendo las instrucciones y ayudas para resolver la práctica. En cualquier caso, es necesario responder a todas y cada una de las siguientes tareas.
#
# ## Parte obligatoria

# %% [markdown]
# En primer lugar vamos a importar los paquetes que usaremos a lo largo de la práctica. Para representar los datos usaremos *pandas*, para realizar los calculos y medidas *numpy* y *scikit-learn*. Para el procesamiento de lenguaje natural *spacy*. EL modulo *pprint*, pretty print, sirve para imprimir de manera bonita por pantalla Se proporciona un documento con las instrucciones de instalación, por favor consultarlo antes de empezar la práctica.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

import spacy
from spacy.lang.en.stop_words import STOP_WORDS

from pprint import pprint

# %% [markdown]
# ### TAREA 1. Recomendador basado en popularidad.
# En primer lugar es necesario cargar y preprocesar la base de datos descargada. Por favor coloca el fichero CSV con la descarga de IMDB en el mismo directorio que este notebook y utilizar el comando *pd.read_csv* para cargarlo. Posteriormente puedes usar df.info() para visualizar una descripción de las columnas de la base de datos. Para usar pandas puedes consultar la documentación en [Pandas Docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html)

# %%
df = pd.read_csv('IMDBdata_MainData.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5273 entries, 0 to 5272
# Data columns (total 27 columns):
# Title             5273 non-null object
# Year              5273 non-null int64
# Rated             4815 non-null object
# Released          5235 non-null object
# Runtime           5257 non-null object
# Genre             5271 non-null object
# Director          5272 non-null object
# Writer            5221 non-null object
# Actors            5266 non-null object
# Plot              5262 non-null object
# Language          5263 non-null object
# Country           5271 non-null object
# Awards            4462 non-null object
# Poster            5260 non-null object
# Ratings.Source    5273 non-null object
# Ratings.Value     5273 non-null object
# Metascore         3876 non-null float64
# imdbRating        5273 non-null float64
# imdbVotes         5273 non-null object
# imdbID            5273 non-null object
# Type              5273 non-null object
# DVD               4882 non-null object
# BoxOffice         2634 non-null object
# Production        4945 non-null object
# Website           3472 non-null object
# Response          5273 non-null bool
# tomatoURL         5187 non-null object
# dtypes: bool(1), float64(2), int64(1), object(23)
# memory usage: 1.1+ MB

# %% [markdown]
# Nos quedaremos con un subconjunto de la base de datos para el resto, en concreto, las columnas "Title","Genre","Director","Actors","Plot","Year","Rated","Runtime","imdbRating","imdbVotes" y las filas correspondientes a las 1000 películas más votadas en IMDB. Para ver las primeras filas de la tabla de datos podemos usar *df.head*.

# %%
df = df[["Title","Genre","Director","Actors","Plot","Year","Rated","Runtime","imdbRating","imdbVotes"]]
df["imdbVotes"] = df["imdbVotes"].str.replace(",","").astype(float)
df = df.sort_values("imdbVotes",ascending=False)

# %%
df.head(10)
# Out:
#                                                  Title  \
# 100                           The Shawshank Redemption
# 103                                    The Dark Knight
# 112                                          Inception
# 108                                         Fight Club
# 107                                       Pulp Fiction
# 110                                       Forrest Gump
# 109  The Lord of the Rings: The Fellowship of the Ring
# 116                                         The Matrix
# 106      The Lord of the Rings: The Return of the King
# 101                                      The Godfather
#
#                          Genre                         Director  \
# 100               Crime, Drama                   Frank Darabont
# 103       Action, Crime, Drama                Christopher Nolan
# 112  Action, Adventure, Sci-Fi                Christopher Nolan
# 108                      Drama                    David Fincher
# 107               Crime, Drama                Quentin Tarantino
# 110     Comedy, Drama, Romance                  Robert Zemeckis
# 109  Adventure, Drama, Fantasy                    Peter Jackson
# 116             Action, Sci-Fi  Lana Wachowski, Lilly Wachowski
# 106  Adventure, Drama, Fantasy                    Peter Jackson
# 101               Crime, Drama             Francis Ford Coppola
#
#                                                 Actors  \
# 100  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 103  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 112  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 108  Edward Norton, Brad Pitt, Meat Loaf, Zach Grenier
# 107  Tim Roth, Amanda Plummer, Laura Lovelace, John...
# 110  Tom Hanks, Rebecca Williams, Sally Field, Mich...
# 109  Alan Howard, Noel Appleby, Sean Astin, Sala Baker
# 116  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 106   Noel Appleby, Ali Astin, Sean Astin, David Aston
# 101  Marlon Brando, Al Pacino, James Caan, Richard ...
#
#                                                   Plot  Year  Rated  Runtime  \
# 100  Two imprisoned men bond over a number of years...  1994      R  142 min
# 103  When the menace known as the Joker emerges fro...  2008  PG-13  152 min
# 112  A thief, who steals corporate secrets through ...  2010  PG-13  148 min
# 108  An insomniac office worker, looking for a way ...  1999      R  139 min
# 107  The lives of two mob hit men, a boxer, a gangs...  1994      R  154 min
# 110  While not intelligent, Forrest Gump has accide...  1994  PG-13  142 min
# 109  A meek Hobbit from the Shire and eight compani...  2001  PG-13  178 min
# 116  A computer hacker learns from mysterious rebel...  1999      R  136 min
# 106  Gandalf and Aragorn lead the World of Men agai...  2003  PG-13  201 min
# 101  The aging patriarch of an organized crime dyna...  1972      R  175 min
#
#      imdbRating  imdbVotes
# 100         9.3  1825626.0
# 103         9.0  1802351.0
# 112         8.8  1592306.0
# 108         8.8  1458676.0
# 107         8.9  1427451.0
# 110         8.8  1365937.0
# 109         8.8  1326876.0
# 116         8.7  1314628.0
# 106         8.9  1304569.0
# 101         9.2  1243444.0

# %% [markdown]
# Ahora vamos a cargar el perfil de votos de dos usuarios, simplemente ejecuta el siguiente codigo y convertiremos la lista de nombres de películas en tablas con toda la información de la base de datos.

# %%
user_votes1 = [ "Sin City","Match Point","Pulp Fiction",
                 "Jurassic Park","The Shawshank Redemption",
                 "Blade Runner","Annie Hall","The Godfather",
                 "The Great Escape","Psycho","Casablanca","The Social Network"]
user_votes2 = [ "Slumdog Millionaire","Grease", "Black Swan", "The Illusionist", "Ice Age",
               "Shrek", "Pretty Woman","Silver Linings Playbook"]
def get_user_profile(user_votes,df_):
    indexes = np.array([df_.loc[df_['Title'] == film_name].index.values[0] for film_name in user_votes])
    return df_.loc[indexes]

user_profile1 = get_user_profile(user_votes1,df)
user_profile2 = get_user_profile(user_votes2,df)
display("User Profile 1")
display(user_profile1)
display("User Profile 2")
display(user_profile2)
# Out:
# 'User Profile 1'
#                          Title                        Genre  \
# 315                   Sin City              Crime, Thriller
# 3115               Match Point        Drama, Romance, Sport
# 107               Pulp Fiction                 Crime, Drama
# 263              Jurassic Park  Adventure, Sci-Fi, Thriller
# 100   The Shawshank Redemption                 Crime, Drama
# 208               Blade Runner             Sci-Fi, Thriller
# 275                 Annie Hall              Comedy, Romance
# 101              The Godfather                 Crime, Drama
# 195           The Great Escape    Adventure, Drama, History
# 130                     Psycho    Horror, Mystery, Thriller
# 128                 Casablanca          Drama, Romance, War
# 1769        The Social Network             Biography, Drama
#
#                                                Director  \
# 315   Frank Miller, Robert Rodriguez, Quentin Tarantino
# 3115                                        Woody Allen
# 107                                   Quentin Tarantino
# 263                                    Steven Spielberg
# 100                                      Frank Darabont
# 208                                        Ridley Scott
# 275                                         Woody Allen
# 101                                Francis Ford Coppola
# 195                                        John Sturges
# 130                                    Alfred Hitchcock
# 128                                      Michael Curtiz
# 1769                                      David Fincher
#
#                                                  Actors  \
# 315   Jessica Alba, Devon Aoki, Alexis Bledel, Power...
# 3115  Jonathan Rhys Meyers, Alexander Armstrong, Pau...
# 107   Tim Roth, Amanda Plummer, Laura Lovelace, John...
# 263   Sam Neill, Laura Dern, Jeff Goldblum, Richard ...
# 100   Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 208   Harrison Ford, Rutger Hauer, Sean Young, Edwar...
# 275   Woody Allen, Diane Keaton, Tony Roberts, Carol...
# 101   Marlon Brando, Al Pacino, James Caan, Richard ...
# 195   Steve McQueen, James Garner, Richard Attenboro...
# 130   Anthony Perkins, Vera Miles, John Gavin, Janet...
# 128   Humphrey Bogart, Ingrid Bergman, Paul Henreid,...
# 1769  Jesse Eisenberg, Rooney Mara, Bryan Barter, Du...
#
#                                                    Plot  Year     Rated  \
# 315   A film that explores the dark and miserable to...  2005         R
# 3115  At a turning point in his life, a former tenni...  2005         R
# 107   The lives of two mob hit men, a boxer, a gangs...  1994         R
# 263   During a preview tour, a theme park suffers a ...  1993     PG-13
# 100   Two imprisoned men bond over a number of years...  1994         R
# 208   A blade runner must pursue and try to terminat...  1982         R
# 275   Neurotic New York comedian Alvy Singer falls i...  1977        PG
# 101   The aging patriarch of an organized crime dyna...  1972         R
# 195   Allied prisoners of war plan for several hundr...  1963  APPROVED
# 130   A Phoenix secretary embezzles $40,000 from her...  1960  APPROVED
# 128   In Casablanca in December 1941, a cynical Amer...  1942        PG
# 1769  Harvard student Mark Zuckerberg creates the so...  2010     PG-13
#
#       Runtime  imdbRating  imdbVotes
# 315   124 min         8.0   685825.0
# 3115  124 min         7.7   176391.0
# 107   154 min         8.9  1427451.0
# 263   127 min         8.1   670652.0
# 100   142 min         9.3  1825626.0
# 208   117 min         8.2   499344.0
# 275    93 min         8.1   208523.0
# 101   175 min         9.2  1243444.0
# 195   172 min         8.2   177901.0
# 130   109 min         8.5   458316.0
# 128   102 min         8.5   415400.0
# 1769  120 min         7.7   514092.0
# 'User Profile 2'
#                         Title                         Genre  \
# 349       Slumdog Millionaire                         Drama
# 3954                   Grease              Musical, Romance
# 3268               Black Swan               Drama, Thriller
# 2991          The Illusionist       Drama, Mystery, Romance
# 1258                  Ice Age  Animation, Adventure, Comedy
# 1512                    Shrek  Animation, Adventure, Comedy
# 3207             Pretty Woman               Comedy, Romance
# 2638  Silver Linings Playbook        Comedy, Drama, Romance
#
#                           Director  \
# 349   Danny Boyle, Loveleen Tandan
# 3954                Randal Kleiser
# 3268              Darren Aronofsky
# 2991                   Neil Burger
# 1258  Chris Wedge, Carlos Saldanha
# 1512  Andrew Adamson, Vicky Jenson
# 3207                Garry Marshall
# 2638              David O. Russell
#
#                                                  Actors  \
# 349   Dev Patel, Saurabh Shukla, Anil Kapoor, Raj Zu...
# 3954  John Travolta, Olivia Newton-John, Stockard Ch...
# 3268  Natalie Portman, Mila Kunis, Vincent Cassel, B...
# 2991  Edward Norton, Paul Giamatti, Jessica Biel, Ru...
# 1258  Ray Romano, John Leguizamo, Denis Leary, Goran...
# 1512  Mike Myers, Eddie Murphy, Cameron Diaz, John L...
# 3207  Richard Gere, Julia Roberts, Ralph Bellamy, Ja...
# 2638  Bradley Cooper, Jennifer Lawrence, Robert De N...
#
#                                                    Plot  Year  Rated  Runtime  \
# 349   A Mumbai teen reflects on his upbringing in th...  2008      R  120 min
# 3954  Good girl Sandy and greaser Danny fell in love...  1978  PG-13  110 min
# 3268  A committed dancer wins the lead role in a pro...  2010      R  108 min
# 2991  In turn-of-the-century Vienna, a magician uses...  2006  PG-13  110 min
# 1258  Set during the Ice Age, a sabertooth tiger, a ...  2002     PG   81 min
# 1512  After his swamp is filled with magical creatur...  2001     PG   90 min
# 3207  A man in a legal but hurtful business needs an...  1990      R  119 min
# 2638  After a stint in a mental institution, former ...  2012      R  122 min
#
#       imdbRating  imdbVotes
# 349          8.0   679975.0
# 3954         7.2   181489.0
# 3268         8.0   583669.0
# 2991         7.6   311847.0
# 1258         7.6   349351.0
# 1512         7.9   498387.0
# 3207         6.9   229383.0
# 2638         7.8   567777.0

# %% [markdown]
# Una vez organizada la base de datos, vamos a generar un recomendador basado en popularidad que recomiende en función del *imdbRating*. Recuerda que para ordenar los valores de un pandas dataframe se puede usar *df.sort_values* y con *df.head* mostramos los primeros valores. ¿Qué 20 películas recomendaría al usuario 1 y al usuario 2? ¿Qué podemos comentar de esas dos listas?

# %%
 # <<RELLENAR: Recomendador basado en popularidad>>
display("Top 20")
display(df.sort_values(by='imdbRating',ascending=False).head(20))
# Out:
# 'Top 20'
#                                                  Title  \
# 100                           The Shawshank Redemption
# 101                                      The Godfather
# 102                             The Godfather: Part II
# 103                                    The Dark Knight
# 351                                           Drishyam
# 600                     The Good, the Bad and the Ugly
# 107                                       Pulp Fiction
# 104                                       12 Angry Men
# 106      The Lord of the Rings: The Return of the King
# 353                                         Anbe Sivam
# 105                                   Schindler's List
# 350                                              Anand
# 352                                            Nayakan
# 111     Star Wars: Episode V - The Empire Strikes Back
# 367                        Baahubali 2: The Conclusion
# 449                                       RangiTaranga
# 108                                         Fight Club
# 110                                       Forrest Gump
# 112                                          Inception
# 109  The Lord of the Rings: The Fellowship of the Ring
#
#                           Genre              Director  \
# 100                Crime, Drama        Frank Darabont
# 101                Crime, Drama  Francis Ford Coppola
# 102                Crime, Drama  Francis Ford Coppola
# 103        Action, Crime, Drama     Christopher Nolan
# 351      Crime, Drama, Thriller         Jeethu Joseph
# 600                     Western          Sergio Leone
# 107                Crime, Drama     Quentin Tarantino
# 104                Crime, Drama          Sidney Lumet
# 106   Adventure, Drama, Fantasy         Peter Jackson
# 353    Adventure, Comedy, Drama             Sundar C.
# 105   Biography, Drama, History      Steven Spielberg
# 350                       Drama  Hrishikesh Mukherjee
# 352                Crime, Drama           Mani Ratnam
# 111  Action, Adventure, Fantasy        Irvin Kershner
# 367    Action, Adventure, Drama        S.S. Rajamouli
# 449   Adventure, Music, Mystery         Anup Bhandari
# 108                       Drama         David Fincher
# 110      Comedy, Drama, Romance       Robert Zemeckis
# 112   Action, Adventure, Sci-Fi     Christopher Nolan
# 109   Adventure, Drama, Fantasy         Peter Jackson
#
#                                                 Actors  \
# 100  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 101  Marlon Brando, Al Pacino, James Caan, Richard ...
# 102  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 103  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 351                    Mohanlal, Meena, Ansiba, Esther
# 600  Eli Wallach, Clint Eastwood, Lee Van Cleef, Al...
# 107  Tim Roth, Amanda Plummer, Laura Lovelace, John...
# 104  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 106   Noel Appleby, Ali Astin, Sean Astin, David Aston
# 353       Kamal Haasan, Madhavan, Kiran Rathod, Nassar
# 105  Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...
# 350  Rajesh Khanna, Amitabh Bachchan, Sumita Sanyal...
# 352  Kamal Haasan, Saranya Ponvannan, Delhi Ganesh,...
# 111  Mark Hamill, Harrison Ford, Carrie Fisher, Bil...
# 367  Prabhas, Rana Daggubati, Anushka Shetty, Taman...
# 449  Nirup Bhandari, Radhika Chetan, Avantika Shett...
# 108  Edward Norton, Brad Pitt, Meat Loaf, Zach Grenier
# 110  Tom Hanks, Rebecca Williams, Sally Field, Mich...
# 112  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 109  Alan Howard, Noel Appleby, Sean Astin, Sala Baker
#
#                                                   Plot  Year      Rated  \
# 100  Two imprisoned men bond over a number of years...  1994          R
# 101  The aging patriarch of an organized crime dyna...  1972          R
# 102  The early life and career of Vito Corleone in ...  1974          R
# 103  When the menace known as the Joker emerges fro...  2008      PG-13
# 351  A man goes to extreme lengths to save his fami...  2013  NOT RATED
# 600  A bounty hunting scam joins two men in an unea...  1966   APPROVED
# 107  The lives of two mob hit men, a boxer, a gangs...  1994          R
# 104  A jury holdout attempts to prevent a miscarria...  1957   APPROVED
# 106  Gandalf and Aragorn lead the World of Men agai...  2003      PG-13
# 353  Two men, one young and arrogant, the other dam...  2003  NOT RATED
# 105  In German-occupied Poland during World War II,...  1993          R
# 350  The story of a terminally ill man who wishes t...  1971  NOT RATED
# 352  A common man's struggles against a corrupt pol...  1987  NOT RATED
# 111  After the rebels are overpowered by the Empire...  1980         PG
# 367  When Shiva, the son of Bahubali, learns about ...  2017        NaN
# 449  Mysterious events begin to unfold after a recl...  2015  NOT RATED
# 108  An insomniac office worker, looking for a way ...  1999          R
# 110  While not intelligent, Forrest Gump has accide...  1994      PG-13
# 112  A thief, who steals corporate secrets through ...  2010      PG-13
# 109  A meek Hobbit from the Shire and eight compani...  2001      PG-13
#
#      Runtime  imdbRating  imdbVotes
# 100  142 min         9.3  1825626.0
# 101  175 min         9.2  1243444.0
# 102  202 min         9.0   856870.0
# 103  152 min         9.0  1802351.0
# 351  160 min         8.9    15405.0
# 600  178 min         8.9   539526.0
# 107  154 min         8.9  1427451.0
# 104   96 min         8.9   494215.0
# 106  201 min         8.9  1304569.0
# 353  160 min         8.9     8928.0
# 105  195 min         8.9   937837.0
# 350  122 min         8.9    16396.0
# 352  145 min         8.8     8728.0
# 111  124 min         8.8   910608.0
# 367  167 min         8.8    42582.0
# 449  149 min         8.8     9869.0
# 108  139 min         8.8  1458676.0
# 110  142 min         8.8  1365937.0
# 112  148 min         8.8  1592306.0
# 109  178 min         8.8  1326876.0

# %% [markdown]
# El recomendador de popularidad no entrega una lista personalizada porque no será diferente para el usuario 1 y el usuario 2. Estas recomendaciones se basan en un promedio de puntuación que le han dado los usuarios y muestra un Top, en este caso un Top 20, de las peliculas más vistas/con mayor promedio de clasificación hasta el momento.

# %% [markdown]
# ### TAREA 2. Recomendador basado en genero y año de la película.
#
# En esta segunda parte vamos a extraer el género de la película y el año y vamos a construir un recomendador basado en contenido. El código es una variable categórica, para poder codificarla numericamente utilizaremos lo que se denominan dummy variables, es decir una variable binaria por cada genero. Podeis verlo explicado [aquí](https://en.wikipedia.org/wiki/Dummy_variable_(statistics)). Además vamos a rellenar con 0's aquellos valores vacíos de la base de datos.

# %%
f = 'Genre'
df[f] = df[f].str.replace(' ', '')
X_dummy = df[f].str.get_dummies(',').add_prefix(f + '.')
df = df.drop([f], axis = 1)
df= pd.concat((df, X_dummy), axis = 1)
df = df.fillna(0)

df.head()
# Out:
#                         Title           Director  \
# 100  The Shawshank Redemption     Frank Darabont
# 103           The Dark Knight  Christopher Nolan
# 112                 Inception  Christopher Nolan
# 108                Fight Club      David Fincher
# 107              Pulp Fiction  Quentin Tarantino
#
#                                                 Actors  \
# 100  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 103  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 112  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 108  Edward Norton, Brad Pitt, Meat Loaf, Zach Grenier
# 107  Tim Roth, Amanda Plummer, Laura Lovelace, John...
#
#                                                   Plot  Year  Rated  Runtime  \
# 100  Two imprisoned men bond over a number of years...  1994      R  142 min
# 103  When the menace known as the Joker emerges fro...  2008  PG-13  152 min
# 112  A thief, who steals corporate secrets through ...  2010  PG-13  148 min
# 108  An insomniac office worker, looking for a way ...  1999      R  139 min
# 107  The lives of two mob hit men, a boxer, a gangs...  1994      R  154 min
#
#      imdbRating  imdbVotes  Genre.Action  ...  Genre.Musical  Genre.Mystery  \
# 100         9.3  1825626.0             0  ...              0              0
# 103         9.0  1802351.0             1  ...              0              0
# 112         8.8  1592306.0             1  ...              0              0
# 108         8.8  1458676.0             0  ...              0              0
# 107         8.9  1427451.0             0  ...              0              0
#
#      Genre.News  Genre.Romance  Genre.Sci-Fi  Genre.Short  Genre.Sport  \
# 100           0              0             0            0            0
# 103           0              0             0            0            0
# 112           0              0             1            0            0
# 108           0              0             0            0            0
# 107           0              0             0            0            0
#
#      Genre.Thriller  Genre.War  Genre.Western
# 100               0          0              0
# 103               0          0              0
# 112               0          0              0
# 108               0          0              0
# 107               0          0              0
#
# [5 rows x 33 columns]

# %%
# Extract interesting columns
genre_year_matrix = df[['Year','Genre.Action', 'Genre.Adventure',
       'Genre.Animation', 'Genre.Biography', 'Genre.Comedy', 'Genre.Crime', 'Genre.Drama', 'Genre.Family', 'Genre.Fantasy',
       'Genre.Film-Noir', 'Genre.History', 'Genre.Horror', 'Genre.Music',
       'Genre.Musical', 'Genre.Mystery',  'Genre.Romance',
       'Genre.Sci-Fi',  'Genre.Sport', 'Genre.Thriller',
       'Genre.War', 'Genre.Western']].to_numpy()

# %% [markdown]
# Posteriormente, para construir el recomendador primero hay que construir la matriz de similitud de todos los ítems y devolver los K ítems más parecidos al perfil de cada usuario. La similitud que usaremos será la similitud del coseno usando un solo argumento, podeis ver la documentación de scikit-learn [aqui](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html). Posterioremente hay que devolver los Top-K items con mayor similaridad a los del perfil del usuario.

# %%
def get_content_based_recommendation(movie_df, data_matrix, user_profile,topk = 20):
    sims = cosine_similarity(data_matrix,Y=None,dense_output=True) # <<RELLENAR: Similiritud del coseno a partir de data_matrix>>
    
    # Extraer las similiritudes de los elementos puntuados
    positions = [ movie_df.index.get_loc(elem) for elem in user_profile.index.tolist()]
    sims_user = sims[positions,:]
    
    # Devuelve los topk más parecidos a los puntuados.
    shape_sims_user = sims_user.shape
    linear_recommend = np.argsort(sims_user,axis=None)[::-1]
    recommend = pd.unique(np.unravel_index(linear_recommend, shape_sims_user)[1])
    recommend = recommend[~np.in1d(recommend,positions)][:topk]
    return recommend

# %% [markdown]
# ¿Qué 10 películas recomendaría al usuario 1 y al usuario 2? ¿Qué podemos comentar de esas dos listas?

# %%
recommendations1 = get_content_based_recommendation(df,genre_year_matrix,user_profile1,topk=10) # <<RELLENAR: Recomendador basado en genero y año, usuario 1>>
display('User 1')
display(df.iloc[recommendations1][["Title","imdbRating"]])
recommendations2 = get_content_based_recommendation(df,genre_year_matrix,user_profile2,topk=10) # <<RELLENAR: Recomendador basado en genero y año, usuario 2>>
display('User 2')
display(df.iloc[recommendations2][["Title","imdbRating"]])
# Out:
# 'User 1'
#                        Title  imdbRating
# 329        The King's Speech         8.0
# 2088  Goal! The Dream Begins         6.8
# 3563    My Week with Marilyn         7.0
# 3219           The Iron Lady         6.4
# 2583      Coco Before Chanel         6.7
# 1557                Firewall         5.8
# 894           Ocean's Twelve         6.5
# 3456        Dead Man Walking         7.6
# 210                   Casino         8.2
# 5261                    Bang         6.4
# 'User 2'
#                            Title  imdbRating
# 3632                  Free Style         4.3
# 2629                       Stone         5.4
# 3221  Jonah: A VeggieTales Movie         6.6
# 224                  Gran Torino         8.2
# 2522         Me and Orson Welles         6.8
# 4367                   The Class         7.5
# 4911         Harrison Montgomery         7.3
# 4865                   Childless         6.0
# 3459     The Secret Life of Bees         7.3
# 5073              Wendy and Lucy         7.1

# %% [markdown]
# Este recomendador basado en el genero y año de la película presenta a los usuarios una recomendación personalizada. Realiza un calculo de similitud entre las peliculas que ha visto el usuario, es decir, su perfil y las demás peliculas de la lista.
# Al tener una similitud teniendo en cuenta las variables genero y año puede dar un Top 10 de peliculas que pueden gustarle al usuario basado en sus vistas anteriores.

# %% [markdown]
# ### TAREA 3. Recomendador basado en el argumento.
# En esta parte construiremos un recomendador basado en el argumento. Lo haremos de dos formas, en primer lugar usando una representación del mismo basada en bolsas de palabras y posteriormente usando vectores word2vec. En primer lugar extraeremos los plots del data frame, usando el nombre de la columna y el método *to_numpy*. Alguno de los plots eran un NaN por lo que ahora es 0, lo convertimos todo en strings y en minuscula.

# %%
plots =df["Plot"].to_numpy()
plots_clean = [ str(plot).lower() for plot in plots]
plots_clean
# Out:
# ['two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#  'when the menace known as the joker emerges from his mysterious past, he wreaks havoc and chaos on the people of gotham, the dark knight must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#  'a thief, who steals corporate secrets through use of dream-sharing technology, is given the inverse task of planting an idea into the mind of a ceo.',
#  'an insomniac office worker, looking for a way to change his life, crosses paths with a devil-may-care soap maker, forming an underground fight club that evolves into something much, much more.',
#  "the lives of two mob hit men, a boxer, a gangster's wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
#  'while not intelligent, forrest gump has accidentally been present at many historic moments, but his true love, jenny curran, eludes him.',
#  'a meek hobbit from the shire and eight companions set out on a journey to destroy the powerful one ring and save middle earth from the dark lord sauron.',
#  'a computer hacker learns from mysterious rebels about the true nature of his reality and his role in the war against its controllers.',
#  "gandalf and aragorn lead the world of men against sauron's army to draw his gaze from frodo and sam as they approach mount doom with the one ring.",
#  'the aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.',
#  "eight years after the joker's reign of anarchy, the dark knight, with the help of the enigmatic selina, is forced from his imposed exile to save gotham city, now on the edge of total annihilation, from the brutal guerrilla terrorist bane.",
#  "while frodo and sam edge closer to mordor with the help of the shifty gollum, the divided fellowship makes a stand against sauron's new ally, saruman, and his hordes of isengard.",
#  'two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#  "when a roman general is betrayed and his family murdered by an emperor's corrupt son, he comes to rome as a gladiator to seek revenge.",
#  "a team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
#  'after training with his mentor, batman begins his fight to free crime-ridden gotham city from the corruption that scarecrow and the league of shadows have cast upon it.',
#  "earth's mightiest heroes must come together and learn to fight as a team if they are to stop the mischievous loki and his alien army from enslaving humanity.",
#  'with the help of a german bounty hunter , a freed slave sets out to rescue his wife from a brutal mississippi plantation owner.',
#  "luke skywalker joins forces with a jedi knight, a cocky pilot, a wookiee and two droids to save the galaxy from the empire's world-destroying battle-station, while also attempting to rescue princess leia from the evil darth vader.",
#  "in nazi-occupied france during world war ii, a plan to assassinate nazi leaders by a group of jewish u.s. soldiers coincides with a theatre owner's vengeful plans for the same.",
#  'a young f.b.i. cadet must confide in an incarcerated and manipulative killer to receive his help on catching another serial killer who skins his victims.',
#  'following the normandy landings, a group of u.s. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.',
#  'an undercover cop and a mole in the police attempt to identify each other while infiltrating an irish gang in south boston.',
#  'a paraplegic marine dispatched to the moon pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.',
#  'in german-occupied poland during world war ii, oskar schindler gradually becomes concerned for his jewish workforce after witnessing their persecution by the nazi germans.',
#  'two stage magicians engage in competitive one-upmanship in an attempt to create the ultimate stage illusion.',
#  'after the rebels are overpowered by the empire on their newly established base, luke skywalker begins jedi training with master yoda. his friends accept shelter from a questionable ally as darth vader hunts them in a plan to capture luke.',
#  "a man juggles searching for his wife's murderer and keeping his short-term memory loss from being an obstacle.",
#  "a sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.",
#  'based on the true story of jordan belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.',
#  'blacksmith will turner teams up with eccentric pirate ""captain"" jack sparrow to save his love, the governor\'s daughter, from jack\'s former pirate allies, who are now undead.',
#  'in 1954, a u.s. marshal investigates the disappearance of a murderess who escaped from a hospital for the criminally insane.',
#  'the lives of guards on death row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.',
#  'the early life and career of vito corleone in 1920s new york is portrayed while his son, michael, expands and tightens his grip on the family crime syndicate.',
#  'in a future british tyranny, a shadowy freedom fighter, known only by the alias of ""v"", plots to overthrow it with the help of a young woman.',
#  'a seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated r.m.s. titanic.',
#  'a former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.',
#  'a cyborg, identical to the one who failed to kill sarah connor, must now protect her ten year old son, john connor, from a more advanced cyborg.',
#  'marty mcfly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling delorean invented by his close friend, the maverick scientist doc brown.',
#  'a sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.',
#  'when his secret bride is executed for assaulting an english soldier who tried to rape her, sir william wallace begins a revolt against king edward i of england.',
#  'the bride wakens from a four-year coma. the child she carried in her womb is gone. now she must wreak vengeance on the team of assassins who betrayed her - a team she was once part of.',
#  'the story of henry hill and his life through the teen years into the years of mafia, covering his relationship with wife karen hill and his mob partners jimmy conway and tommy devitto in the italian-american crime syndicate.',
#  "mathilda, a 12-year-old girl, is reluctantly taken in by léon, a professional assassin, after her family is murdered. léon and mathilda form an unusual relationship, as she becomes his protégée and learns the assassin's trade.",
#  'in the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.',
#  'a group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#  'after his son is captured in the great barrier reef and taken to sydney, a timid clownfish sets out on a journey to bring him home.',
#  "a boy who communicates with spirits that don't know they're dead seeks the help of a disheartened child psychologist.",
#  "after a daring mission to rescue han solo from jabba the hutt, the rebels dispatch to endor to destroy a more powerful death star. meanwhile, luke struggles to help vader back from the dark side without falling into the emperor's trap.",
#  'after being held captive in an afghan cave, billionaire engineer tony stark creates a unique weaponized suit of armor to fight evil.',
#  "katniss everdeen voluntarily takes her younger sister's place in the hunger games: a televised competition in which two teenagers from each of the twelve districts of panem are chosen at random to fight to the death.",
#  'a criminal pleads insanity after getting into trouble again and once in the mental institution rebels against the oppressive nurse and rallies up the scared patients.',
#  'seventy-eight year old carl fredricksen travels to paradise falls in his home equipped with balloons, inadvertently taking a young stowaway.',
#  'an insurance salesman/adjuster discovers his entire life is actually a television show.',
#  'after a simple jewelry heist goes terribly wrong, the surviving criminals begin to suspect that one of them is a police informant.',
#  'when their relationship turns sour, a couple undergoes a procedure to have each other erased from their memories. but it is only through the process of loss that they discover what they had to begin with.',
#  'archaeologist and adventurer indiana jones is hired by the u.s. government to find the ark of the covenant before the nazis.',
#  'lion cub and future king simba searches for his identity. his eagerness to please others and penchant for testing his boundaries sometimes gets him into trouble.',
#  'a film that explores the dark and miserable town, basin city, and tells the story of three different people, all caught up in violent corruption.',
#  "a cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#  'a mumbai teen reflects on his upbringing in the slums when he is accused of cheating on the indian version of ""who wants to be a millionaire?""',
#  'a reluctant hobbit, bilbo baggins, sets out to the lonely mountain with a spirited group of dwarves to reclaim their mountain home - and the gold within it - from the dragon smaug.',
#  'during a preview tour, a theme park suffers a major power breakdown that allows its cloned dinosaur exhibits to run amok.',
#  'after john nash, a brilliant but asocial mathematician, accepts secret work in cryptography, his life takes a turn for the nightmarish.',
#  'violence and mayhem ensue after a hunter stumbles upon a drug deal gone wrong and more than two million dollars in cash near the rio grande.',
#  "three decades after the empire's defeat, a new threat arises in the militant first order. stormtrooper defector finn and spare parts scavenger rey are caught up in the resistance's search for the missing luke skywalker.",
#  'a family heads to an isolated hotel for the winter where an evil and spiritual presence influences the father into violence, while his psychic son sees horrific forebodings from the past and of the future.',
#  'will hunting, a janitor at m.i.t., has a gift for mathematics, but needs help from a psychologist to find direction in his life.',
#  'a seemingly indestructible humanoid cyborg is sent from 2029 to 1984 to assassinate a waitress, whose unborn son will lead humanity in a war against the machines, while a soldier from that war is sent to protect her at all costs.',
#  'a fast-talking mercenary with a morbid sense of humor is subjected to a rogue experiment that leaves him with accelerated healing powers and a quest for revenge.',
#  'unscrupulous boxing promoters, violent bookmakers, a russian gangster, incompetent amateur robbers, and supposedly jewish jewelers fight to track down a priceless stolen diamond.',
#  "with his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.",
#  'king leonidas of sparta and a force of 300 men fight the persians at thermopylae in 480 b.c.',
#  'in order to power the city, monsters have to scare children so that they scream. however, the children are toxic to the monsters, and after a child gets through, 2 monsters realize things may not be what they think.',
#  'a woman rebels against a tyrannical ruler in postapocalyptic australia in search for her home-land with the help of a group of female prisoners, a psychotic worshipper, and a drifter named max.',
#  'john mcclane, officer of the nypd, tries to save his wife holly gennaro and several others that were taken hostage by german terrorist hans gruber during a christmas party at the nakatomi plaza in los angeles.',
#  'two astronauts work together to survive after an accident which leaves them alone in space.',
#  'a troubled teenager is plagued by visions of a man in a large rabbit suit who manipulates him to commit a series of crimes, after he narrowly escapes a bizarre accident.',
#  'the drug-induced utopias of four coney island people are shattered when their addictions run deep.',
#  'after a space merchant vessel perceives an unknown transmission as a distress call, its landing on the source moon finds one of the crew attacked by a mysterious life-form, and they soon realize that its life cycle has merely begun.',
#  'three buddies wake up from a bachelor party in las vegas, with no memory of the previous night and the bachelor missing. they make their way around the city in order to find their friend before his wedding.',
#  "in future britain, alex delarge, a charismatic and psycopath delinquent, who likes to practice crimes and ultra-violence with his gang, is jailed and volunteers for an experimental aversion therapy developed by the government in an effort to solve society's crime problem - but not all goes according to plan.",
#  "disgruntled korean war veteran walt kowalski sets out to reform his neighbor, a hmong teenager who tried to steal kowalski's prized possession: a 1972 gran torino.",
#  "harry, ron and hermione search for voldemort's remaining horcruxes in their effort to destroy the dark lord as the final battle rages on at hogwarts.",
#  "when tony stark's world is torn apart by a formidable terrorist called the mandarin, he starts an odyssey of rebuilding and retribution.",
#  "the story of 'frank abagnale jr., before his 19th birthday, successfully forged millions of dollars' worth of checks while posing as a pan am pilot, a doctor, and legal prosecutor as a seasoned and dedicated fbi agent pursues him.",
#  "the toys are mistakenly delivered to a day-care center instead of the attic right before andy leaves for college, and it's up to woody to convince the other toys that they weren't abandoned and to return home.",
#  'a committed dancer wins the lead role in a production of tchaikovsky\'s ""swan lake"" only to find herself struggling to maintain her sanity.',
#  'clark kent, one of the last of an extinguished race disguised as an unremarkable human, is forced to reveal his identity when earth is invaded by an army of survivors who threaten to bring the planet to the brink of destruction.',
#  '""the dude"" lebowski, mistaken for a millionaire lebowski, seeks restitution for his ruined rug and enlists his bowling buddies to help get it.',
#  'in miami in 1980, a determined cuban immigrant takes over a drug cartel and succumbs to greed.',
#  'when bitten by a genetically modified spider, a nerdy, shy, and awkward high school student gains spider-like abilities that he eventually must use to fight evil as a superhero after tragedy befalls his family.',
#  'two jedi knights escape a hostile blockade to find allies and come across a young boy who may bring balance to the force, but the long dormant sith resurface to claim their old glory.',
#  'amélie is an innocent and naive girl in paris with her own sense of justice. she decides to help those around her and, along the way, discovers love.',
#  'the powerful but arrogant god thor is cast out of asgard to live amongst humans in midgard (earth), where he soon becomes one of their finest defenders.',
#  'two boys growing up in a violent neighborhood of rio de janeiro take different paths: one becomes a photographer, the other a drug dealer.',
#  'years after a plague kills most of humanity and transforms the rest into monsters, the sole survivor in new york city struggles valiantly to find a cure.',
#  'after a stint in a mental institution, former teacher pat solitano moves back in with his parents and tries to reconcile with his ex-wife. things get more challenging when pat meets tiffany, a mysterious girl with problems of her own.',
#  'after he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.',
#  'three years into the clone wars, the jedi rescue palpatine from count dooku. as obi-wan pursues a new threat, anakin acts as a double agent between the jedi council and palpatine and is lured into a sinister plan to rule the galaxy.',
#  'an astronaut becomes stranded on mars after his team assume him dead, and must rely on his ingenuity to find a way to signal to earth that he is alive.',
#  'an extraterrestrial race forced to live in slum-like conditions on earth suddenly finds a kindred spirit in a government agent who is exposed to their biotechnology.',
#  "with the world now aware of his identity as iron man, tony stark must contend with both his declining health and a vengeful mad man with ties to his father's legacy.",
#  "jack sparrow races to recover the heart of davy jones to avoid enslaving his soul to jones' service, as other friends and foes seek the heart for their own agenda as well.",
#  'the x-men send wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.',
#  "when dr. henry jones sr. suddenly goes missing while pursuing the holy grail, eminent archaeologist indiana jones must follow in his father's footsteps to stop the nazis from getting their hands on the holy grail first.",
#  'in 1962, the united states government enlists the help of mutants with superhuman abilities to stop a malicious dictator who is determined to start world war iii.',
#  'steve rogers, a rejected military soldier transforms into captain america after taking a dose of a ""super-soldier serum"". but being captain america comes at a price as he attempts to take down a war monger and a terrorist organization.',
#  "bond's loyalty to m is tested when her past comes back to haunt her. whilst mi6 comes under attack, 007 must track down and destroy the threat, no matter how personal the cost.",
#  'a mentally unstable vietnam war veteran works as a night-time taxi driver in new york city where the perceived decadence and sleaze feeds his urge for violent action, while attempting to save a preadolescent prostitute in the process.',
#  'a polish jewish musician struggles to survive the destruction of the warsaw ghetto of world war ii.',
#  'as steve rogers struggles to embrace his role in the modern world, he teams up with a fellow avenger and s.h.i.e.l.d agent, black widow, to battle a new threat from history: an assassin known as the winter soldier.',
#  'the bride continues her quest of vengeance against her former boss and lover bill, the reclusive bouncer budd and the treacherous, one-eyed elle.',
#  'a bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.',
#  'the story of king george vi of the united kingdom of great britain and northern ireland, his impromptu ascension to the throne and the speech therapist who helped the unsure monarch become worthy of it.',
#  'the adventures of gustave h, a legendary concierge at a famous hotel from the fictional republic of zubrowka between the first and second world wars, and zero moustafa, the lobby boy who becomes his most trusted friend.',
#  'during world war ii, mathematician alan turing tries to crack the enigma code with help from fellow mathematicians.',
#  'an ancient struggle between two cybertronian races, the heroic autobots and the evil decepticons, comes to earth, with a clue to the ultimate power held by a teenager.',
#  'katniss everdeen and peeta mellark become targets of the capitol after their victory in the 74th hunger games sparks a rebellion in the districts of panem.',
#  'the moon from alien (1979) has been colonized, but contact is lost. this time, the rescue team has impressive firepower, but will it be enough?',
#  "the brash james t. kirk tries to live up to his father's legacy with mr. spock keeping him in check as a vengeful romulan from the future creates black holes to destroy the federation one planet at a time.",
#  'a hapless young viking who aspires to hunt dragons becomes the unlikely friend of a young dragon himself, and learns there may be more to the creatures than he assumed.',
#  'jason bourne dodges a ruthless cia official and his agents from a new assassination program while searching for the origins of his life as a trained killer.',
#  'a pragmatic u.s. marine observes the dehumanizing effects the vietnam war has on his fellow recruits from their brutal boot camp training to the bloody street fighting in hue.',
#  "when tony stark and bruce banner try to jump-start a dormant peacekeeping program called ultron, things go horribly wrong and it's up to earth's mightiest heroes to stop the villainous ultron from enacting his terrible plan.",
#  'a determined woman works with a hardened boxing trainer to become a professional.',
#  'the dwarves, along with bilbo baggins and gandalf the grey, continue their quest to reclaim erebor, their homeland, from smaug. bilbo baggins is in possession of a mysterious and magical ring.',
#  'renton, deeply immersed in the edinburgh drug scene, tries to clean up and get out, despite the allure of the drugs and influence of friends.',
#  'harvard student mark zuckerberg creates the social networking site that would become known as facebook, but is later sued by two brothers who claimed he stole their idea, and the co-founder who was later squeezed out of the business.',
#  'a family of undercover superheroes, while trying to live the quiet suburban life, are forced into action to save the world.',
#  'a rat who can cook makes an unusual alliance with a young kitchen worker at a famous restaurant.',
#  'captain barbossa, will turner and elizabeth swann must sail off the edge of the map, navigate treachery and betrayal, find jack sparrow, and make their final alliances for one last decisive battle.',
#  'a frontiersman on a fur trading expedition in the 1820s fights for survival after being mauled by a bear and left for dead by members of his own hunting team.',
#  'detective sherlock holmes and his stalwart partner watson engage in a battle of wits and brawn with a nemesis whose plot is a threat to all of england.',
#  'a retired cia agent travels across europe and relies on his old skills to save his estranged daughter, who has been kidnapped while on a trip to paris.',
#  'ten years after initially meeting, anakin skywalker shares a forbidden romance with padmé, while obi-wan investigates an assassination attempt on the senator and discovers a secret clone army crafted for the jedi.',
#  'in the falangist spain of 1944, the bookish young stepdaughter of a sadistic army officer escapes into an eerie but captivating fantasy world.',
#  'a blade runner must pursue and try to terminate four replicants who stole a ship in space and have returned to earth to find their creator.',
#  'after his swamp is filled with magical creatures, shrek agrees to rescue princess fiona for a villainous lord in order to get his land back.',
#  'armed with a licence to kill, secret agent james bond sets out on his first mission as 007 and must defeat a weapons dealer in a high stakes game of poker at casino royale, but things are not what they seem.',
#  'former united nations employee gerry lane traverses the world in a race against time to stop the zombie pandemic that is toppling armies and governments, and threatening to destroy humanity itself.',
#  'john bennett, a man whose childhood wish of bringing his teddy bear to life came true, now must decide between keeping the relationship with the bear or his girlfriend, lori.',
#  'a jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.',
#  'an fbi agent and an interpol detective track a team of illusionists who pull off bank heists during their performances and reward their audiences with the money.',
#  'in a future world devastated by disease, a convict is sent back in time to gather information about the man-made virus that wiped out most of the human population on the planet.',
#  "jerry lundegaard's inept crime falls apart due to his and his henchmen's bungling and the persistent police work of the quite pregnant marge gunderson.",
#  'following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.',
#  'in the antebellum united states, solomon northup, a free black man from upstate new york, is abducted and sold into slavery.',
#  'tells the story of benjamin button, a man who starts aging backwards with bizarre consequences.',
#  'rescued from the outrageous neglect of his aunt and uncle, a young boy with a great destiny proves his worth while attending hogwarts school of witchcraft and wizardry.',
#  "a promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#  'two mutants come to a private academy for their kind whose resident superhero team must oppose a terrorist organization with similar powers.',
#  'acting under the cover of a hollywood producer scouting a location for a science fiction film, a cia agent launches a dangerous operation to rescue six americans in tehran during the u.s. hostage crisis in iran in 1980.',
#  'during the vietnam war, captain willard is sent on a dangerous mission into cambodia to assassinate a renegade colonel who has set himself up as a god among a local tribe.',
#  'fearing that the actions of superman are left unchecked, batman takes on the man of steel, while the world wrestles with what kind of a hero it really needs.',
#  "after peter parker is bitten by a genetically altered spider, he gains newfound, spider-like powers and ventures out to solve the mystery of his parent's mysterious death.",
#  'a soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.',
#  'a weatherman finds himself inexplicably living the same day over and over again.',
#  'a young man who survives a disaster at sea is hurtled into an epic journey of adventure and discovery. while cast away, he forms an unexpected connection with another survivor: a fearsome bengal tiger.',
#  'a mysterious hollywood stuntman and mechanic moonlights as a getaway driver and finds himself in trouble when he helps out his neighbor.',
#  "during her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches, and spirits, and where humans are changed into beasts.",
#  'when an open-minded jewish librarian and his son become victims of the holocaust, he uses a perfect mixture of will, humor and imagination to protect his son from the dangers around their camp.',
#  'humanity finds a mysterious, obviously artificial object buried beneath the lunar surface and, with the intelligent computer h.a.l. 9000, sets off on a quest.',
#  'a group of professional bank robbers start to feel the heat from police when they unknowingly leave a clue at their latest heist, while both sides attempt to find balance between their personal lives with their professional lives.',
#  'after graduating from emory university, top student and athlete christopher mccandless abandons his possessions, gives his entire $24,000 savings account to charity and hitchhikes to alaska to live in the wilderness. along the way, christopher encounters a series of characters that shape his life.',
#  "a phoenix secretary embezzles $40,000 from her employer's client, goes on the run, and checks into a remote motel run by a young man under the domination of his mother.",
#  'a new theme park, built on the original site of jurassic park, creates a genetically modified hybrid dinosaur, which escapes containment and goes on a killing spree.',
#  'dave lizewski is an unnoticed high school student and comic book fan who one day decides to become a superhero, even though he has no powers, training or meaningful reason to do so.',
#  "the aliens are coming and their goal is to invade and destroy earth. fighting superior technology, mankind's best weapon is the will to survive.",
#  "in 2074, when the mob wants to get rid of someone, the target is sent into the past, where a hired gun awaits - someone like joe - who one day learns the mob wants to 'close the loop' by sending back joe's future self for assassination.",
#  'when the newly crowned queen elsa accidentally uses her power to turn things into ice to curse her home in infinite winter, her sister, anna, teams up with a mountain man, his playful reindeer, and a snowman to change the weather condition.',
#  'when dr. jane foster gets cursed with a powerful entity known as the aether, thor is heralded of the cosmic event known as the convergence and the genocidal dark elves.',
#  'a giant great white shark arrives on the shores of a new england beach resort and wreaks havoc with bloody attacks on swimmers, until a local sheriff teams up with a marine biologist and an old seafarer to hunt the monster down.',
#  "illustrated upon the progress of his latest broadway play, a former popular actor's struggle to cope with his current life as a wasted actor is shown.",
#  'two co-dependent high school seniors are forced to deal with separation anxiety after their plan to stage a booze-soaked party goes awry.',
#  'a botched card game in london triggers four friends, thugs, weed-growers, hard gangsters, loan sharks and debt collectors to collide with each other in a series of unexpected events, all for the sake of weed, cash and two antique shotguns.',
#  'neo and the rebel leaders estimate that they have 72 hours until 250,000 probes discover zion and destroy it and its inhabitants. during this, neo must decide how he can save trinity from a dark fate in his dreams.',
#  'as corruption grows in 1950s la, three policemen - one strait-laced, one brutal, and one sleazy - investigate a series of murders with their own brand of justice.',
#  'peter parker is beset with troubles in his failing personal life as he battles a brilliant scientist named doctor otto octavius.',
#  "when keller dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts.",
#  'a man is picked up by a fishing boat, bullet-riddled and suffering from amnesia, before racing to elude assassins and regain his memory.',
#  'a pair of underachieving cops are sent back to a local high school to blend in and bring down a synthetic drug ring.',
#  'faced with an unplanned pregnancy, an offbeat young woman makes an unusual decision regarding her unborn child.',
#  "the x-men band together to find a mutant assassin who has made an attempt on the president's life, while the mutant academy is attacked by military forces.",
#  'a police officer joins a secret organization that polices and monitors extraterrestrial interactions on earth.',
#  'danny ocean and his eleven accomplices plan to rob three las vegas casinos simultaneously.',
#  'a fisherman, a smuggler, and a syndicate of businessmen match wits over the possession of a priceless diamond.',
#  'in a future where a special police unit is able to arrest murderers before they commit their crimes, an officer from that unit is himself accused of a future murder.',
#  'a substance, designed to help the brain repair itself, gives rise to a super-intelligent chimp who leads an ape uprising.',
#  'a poor yet passionate young man falls in love with a rich young woman, giving her a sense of freedom, but they are soon separated because of their social differences.',
#  'harry ignores warnings not to return to hogwarts, only to find the school plagued by a series of mysterious attacks and a strange voice haunting him.',
#  'a fedex executive must transform himself physically and emotionally to survive a crash landing on a deserted island.',
#  'a man decides to turn his moribund life around by winning back his ex-girlfriend, reconciling his relationship with his mother, and dealing with an entire community that has returned from the dead to eat the living.',
#  'after young riley is uprooted from her midwest life and moved to san francisco, her emotions - joy, fear, anger, disgust and sadness - conflict on how best to navigate a new city, house, and school.',
#  'a young wizard finds himself competing in a hazard its tournament between rival schools of magic, but he is distracted by recurring nightmares.',
#  'after the crew of the enterprise find an unstoppable force of terror from within their own organization, captain kirk leads a manhunt to a war-zone world to capture a one-man weapon of mass destruction.',
#  "political interference in the avengers' activities causes a rift between former allies captain america and iron man.",
#  'it\'s harry\'s third year at hogwarts; not only does he have a new ""defense against the dark arts"" teacher, but there is also trouble brewing. convicted murderer sirius black has escaped the wizards\' prison and is coming after harry.',
#  'in 2035, a technophobic cop investigates a crime that may have been perpetrated by a robot, which leads to a larger threat to humanity.',
#  'in casablanca in december 1941, a cynical american expatriate encounters a former lover, with unforeseen complications.',
#  'when woody is stolen by a toy collector, buzz and his friends vow to rescue him, but woody finds the idea of immortality in a museum tempting.',
#  "a veteran assigned to extract earth's remaining resources begins to question what he knows about his mission and himself.",
#  'when a criminal mastermind uses a trio of orphan girls as pawns for a grand scheme, he finds their love is profoundly changing him for the better.',
#  'in 1985 where former superheroes exist, the murder of a colleague sends active vigilante rorschach into his own sprawling investigation, uncovering something that could completely change the course of history as we know it.',
#  'a shy student trying to reach his family in ohio, a gun-toting tough guy trying to find the last twinkie, and a pair of sisters trying to get to an amusement park join forces to travel across a zombie-filled america.',
#  'a strange black entity from another world bonds with peter parker and causes inner turmoil as he contends with new villains, temptations, and revenge.',
#  'king arthur and his knights embark on a low-budget search for the grail, encountering many, very silly obstacles.',
#  "when a cure is found to treat mutations, lines are drawn amongst the x-men, led by professor charles xavier, and the brotherhood, a band of powerful mutants organized under xavier's former ally, magneto.",
#  "a soldier wakes up in someone else's body and discovers he's part of an experimental government program to find the bomber of a commuter train. a mission he has only 8 minutes to complete.",
#  'rocky balboa, a small-time boxer, gets a supremely rare chance to fight heavy-weight champion apollo creed in a bout in which he strives to go the distance for his self-respect.',
#  "an adaptation of homer's great epic, the film follows the assault on troy by the united greek forces and chronicles the fates of the men involved.",
#  'a secret government agency recruits some of the most dangerous incarcerated super-villains to form a defensive task force. their first mission: save the world from the apocalypse.',
#  "selfish yuppie charlie babbitt's father left a fortune to his savant brother raymond and a pittance to charlie; they travel cross-country.",
#  'a story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.',
#  'as a war between humankind and monstrous sea creatures wages on, a former pilot and a trainee are paired up to drive a seemingly obsolete special weapon in a desperate effort to save the world from the apocalypse.',
#  "an offbeat romantic comedy about a woman who doesn't believe true love exists, and the young man who falls for her.",
#  'jack sparrow and barbossa embark on a quest to find the elusive fountain of youth, only to discover that blackbeard and his daughter are after it too.',
#  "a middle-aged husband's life changes dramatically when his wife asks him for a divorce. he seeks to rediscover his manhood with the help of a newfound friend, jacob, learning to pick up girls at bars.",
#  "two years after the bachelor party in las vegas, phil, stu, alan, and doug jet to thailand for stu's wedding. stu's plan for a subdued pre-wedding brunch, however, goes seriously awry.",
#  'a lonely writer develops an unlikely relationship with an operating system designed to meet his every need.',
#  "a look at wolverine's early life, in particular his time with the government squad team x and the impact it will have on his later years.",
#  'bilbo and company are forced to engage in a war against an array of combatants and keep the lonely mountain from falling into the hands of a rising darkness.',
#  'after being kidnapped and imprisoned for fifteen years, oh dae-su is released, only to find that he must find his captor in five days.',
#  "with their warning about lord voldemort's return scoffed at, harry and dumbledore are targeted by the wizard authorities as an authoritarian bureaucrat slowly seizes power at hogwarts.",
#  'a writer and wall street trader, nick, finds himself drawn to the past and lifestyle of his millionaire neighbor, jay gatsby.',
#  'in 2027, in a chaotic world in which women have become somehow infertile, a former activist agrees to help transport a miraculously pregnant woman to a sanctuary at sea.',
#  "the imf is shut down when it's implicated in the bombing of the kremlin, causing ethan hunt and his new team to go rogue to clear their organization's name.",
#  'a wealthy new york investment banking executive hides his alternate psychopathic ego from his co-workers and friends as he delves deeper into his violent, hedonistic fantasies.',
#  'the human city of zion defends itself against the massive invasion of the machines as neo fights to end the war at another front while also opposing the rogue agent smith.',
#  'a con man, irving rosenfeld, along with his seductive partner sydney prosser, is forced to work for a wild fbi agent, richie dimaso, who pushes them into a world of jersey powerbrokers and mafia.',
#  'evan treborn suffers blackouts during significant events of his life. as he grows up, he finds a way to remember these lost memories and a supernatural way to alter his life by reading his journal.',
#  'an introvert freshman is taken under the wings of two seniors who welcome him to the real world.',
#  'a gentle man, with scissors for hands, is brought into a new community after living in isolation.',
#  'exceptional london cop nicholas angel is involuntarily transferred to a quaint english village and paired with a witless new partner. while on the beat, nicholas suspects a sinister conspiracy is afoot with the residents.',
#  'los angeles citizens with vastly separate lives collide in interweaving stories of race, loss and redemption.',
#  'a family determined to get their young daughter into the finals of a beauty pageant take a cross-country trip in their vw bus.',
#  'when jason bourne is framed for a cia operation gone awry, he is forced to resume his former life as a trained assassin to survive.',
#  'armed with a super-suit with the astonishing ability to shrink in scale but increase in strength, cat burglar scott lang must embrace his inner hero and help his mentor, dr. hank pym, plan and pull off a heist that will save the world.',
#  'a bored married couple is surprised to learn that they are both assassins hired by competing agencies to kill each other.',
#  'three friends conspire to murder their awful bosses when they realize they are standing in the way of their happiness.',
#  'after visiting 2015, marty mcfly must repeat his visit to 1955 to prevent disastrous changes to 1985...without interfering with his first trip.',
#  'hancock is a superhero whose ill considered behavior regularly causes damage in the millions. he changes when the person he saves helps him improve his public image.',
#  'an insane general triggers a path to nuclear holocaust that a war room full of politicians and generals frantically try to stop.',
#  "a frustrated son tries to determine the fact from fiction in his dying father's life.",
#  'in the colorful future, a cab driver unwittingly becomes the central figure in the search for a legendary cosmic weapon to keep evil and mr zorg at bay.',
#  "in a world divided by factions based on virtues, tris learns she's divergent and won't fit in. when she discovers a plot to destroy divergents, tris and the mysterious four must find out what makes divergents dangerous before it's too late.",
#  'a teenage girl risks everything when she falls in love with a vampire.',
#  "a struggling salesman takes custody of his son as he's poised to begin a life-changing professional career.",
#  'in the year 2154, the very wealthy live on a man-made space station while the rest of the population resides on a ruined earth. a man takes on a mission that could bring equality to the polarized worlds.',
#  'greed, deception, money, power, and murder occur between two best friends: a mafia underboss and a casino owner, for a trophy wife over a gambling empire.',
#  'sherlock holmes and his sidekick dr. watson join forces to outwit and bring down their fiercest adversary, professor moriarty.',
#  'when wolverine is summoned to japan by an old acquaintance, he is embroiled in a conflict that forces him to confront his own demons.',
#  "the youngest son of an alcoholic former boxer returns home, where he's trained by his father for competition in a mixed martial arts tournament - a path that puts the fighter on a collision course with his estranged, older brother.",
#  'with a childhood tragedy that overshadowed their lives, three men are reunited by circumstance when one has a family tragedy.',
#  "navy s.e.a.l. sniper chris kyle's pinpoint accuracy saves countless lives on the battlefield and turns him into a legend. back home to his wife and kids after four tours of duty, however, chris finds that it is the war he can't leave behind.",
#  'a woman, accidentally caught in a dark deal, turns the tables on her captors and transforms into a merciless warrior evolved beyond human logic.',
#  'after arriving in india, indiana jones is asked by a desperate village to find a mystical stone. he agrees, and stumbles upon a secret cult plotting a terrible plan in the catacombs of an ancient palace.',
#  'in 1985 dallas, electrician and hustler ron woodroof works around the system to help aids patients get the medication they need after he is diagnosed with the disease.',
#  'during the iraq war, a sergeant recently assigned to an army bomb squad is put at odds with his squad mates due to his maverick way of handling his work.',
#  'famed archaeologist/adventurer dr. henry ""indiana"" jones is called back into action when he becomes entangled in a soviet plot to uncover the secret behind mysterious artifacts known as the crystal skulls.',
#  'as earth is invaded by alien tripod fighting machines, one family fights for survival.',
#  'as harry potter begins his sixth year at hogwarts, he discovers an old book marked as ""the property of the half-blood prince"" and begins to learn more about lord voldemort\'s dark past.',
#  'jack hall, paleoclimatologist, must make a daring trek across america to reach his son, trapped in the cross-hairs of a sudden international storm which plunges the planet into a new ice age.',
#  'when twelve mysterious spacecraft appear around the world, linguistics professor louise banks is tasked with interpreting the language of the apparent alien visitors.',
#  'journalist mikael blomkvist is aided in his search for a woman who has been missing for forty years by lisbeth salander, a young computer hacker.',
#  "james bond descends into mystery as he tries to stop a mysterious organization from eliminating a country's most valuable resource. all the while, he still tries to seek revenge over the death of his love.",
#  'set during the ice age, a sabertooth tiger, a sloth, and a wooly mammoth find a lost human infant, and they try to return him to his tribe.',
#  'john mcclane and a young hacker join forces to take down master cyber-terrorist thomas gabriel in washington d.c.',
#  'the true story of captain richard phillips and the 2009 hijacking by somali pirates of the u.s.-flagged mv maersk alabama, the first american cargo ship to be hijacked in two hundred years.',
#  'in the dead of a wyoming winter, a bounty hunter and his prisoner find shelter in a cabin currently inhabited by a collection of nefarious characters.',
#  'a young programmer is selected to participate in a ground-breaking experiment in synthetic intelligence by evaluating the human qualities of a breath-taking humanoid a.i.',
#  "a young boy wins a tour through the most magnificent chocolate factory in the world, led by the world's most unusual candy maker.",
#  'bruce banner, a scientist on the run from the u.s. government, must find a cure for the monster he emerges whenever he loses his temper.',
#  "an aspiring author during the civil rights movement of the 1960s decides to write a book detailing the african american maids' point of view on the white families for which they work, and the hardships they go through on a daily basis.",
#  'when new york is put under siege by oscorp, it is up to spider-man to save the city he swore to protect as well as his loved ones.',
#  'an eight-year-old trouble-maker must protect his home from a pair of burglars when he is accidentally left home alone by his family during christmas vacation.',
#  'follows the lives of eight very different couples in dealing with their love lives in various loosely interrelated tales all set during a frantic month before christmas in london, england.',
#  'a wheelchair-bound photographer spies on his neighbours from his apartment window and becomes convinced one of them has committed murder.',
#  'the merciless 1970s rivalry between formula one rivals james hunt and niki lauda.',
#  'a faded movie star and a neglected young woman form an unlikely bond after crossing paths in tokyo.',
#  'the autobots learn of a cybertronian spacecraft hidden on the moon, and race against the decepticons to reach it and to learn its secrets.',
#  'a murder inside the louvre and clues in da vinci paintings lead to the discovery of a religious mystery protected by a secret society for two thousand years -- which could shake the foundations of christianity.',
#  'after discovering that an asteroid the size of texas is going to impact earth in less than a month, n.a.s.a. recruits a misfit team of deep core drillers to save the planet.',
#  "sam witwicky leaves the autobots behind for a normal life. but when his mind is filled with cryptic symbols, the decepticons target him and he is dragged back into the transformers' war.",
#  'a growing nation of genetically evolved apes led by caesar is threatened by a band of human survivors of the devastating virus unleashed a decade earlier.',
#  'in 1970s america, a detective works to bring down the drug empire of frank lucas, a heroin kingpin from manhattan, who is smuggling the drug into the country from the far east.',
#  'thomas is deposited in a community of boys after his memory is erased, soon learning they\'re all trapped in a maze that will require him to join forces with fellow ""runners"" for a shot at escape.',
#  'a young woman whose father has been imprisoned by a terrifying beast offers herself in his place, unaware that her captor is actually a prince, physically altered by a magic spell.',
# ...
#  'a man and a woman are compelled, for legal reasons, to live life as a couple for a limited period of time. at stake is a large amount of money.',
#  'in an alternate victorian age world, a group of famous contemporary fantasy, science fiction, and adventure characters team up on a secret mission.',
#  "the warrior beowulf must fight and defeat the monster grendel who is terrorizing denmark, and later, grendel's mother, who begins killing out of revenge.",
#  "adaptation of james jones' autobiographical 1962 novel, focusing on the conflict at guadalcanal during the second world war.",
#  'in late 1950s new york, tom ripley, a young underachiever, is sent to italy to retrieve dickie greenleaf, a rich and spoiled millionaire playboy. but when the errand fails, ripley takes extreme measures.',
#  'set during wwii, a story seen through the innocent eyes of bruno, the eight-year-old son of the commandant at a german concentration camp, whose forbidden friendship with a jewish boy on the other side of the camp fence has startling and unexpected consequences.',
#  'ex-government operative bryan mills is accused of a ruthless murder he never committed or witnessed. as he is tracked and pursued, mills brings out his particular set of skills to find the true killer and clear his name.',
#  'a gunslinger is embroiled in a war with a local drug runner.',
#  'three backpackers head to a slovak city that promises to meet their hedonistic expectations, with no idea of the hell that awaits them.',
#  "investigating a gold magnate's smuggling, james bond uncovers a plot to contaminate the fort knox gold reserve.",
#  "a gun-for-hire known only as agent 47 hired by a group known only as 'the organization' is ensnared in a political conspiracy, which finds him pursued by both interpol and the russian military as he treks across russia and eastern europe.",
#  'a retired legal counselor writes a novel hoping to find closure for one of his past unresolved homicide cases and for his unreciprocated love with his superior - both of which still haunt him decades later.',
#  'as a cowardly farmer begins to fall for the mysterious new woman in town, he must put his new-found courage to the test when her husband, a notorious gun-slinger, announces his arrival.',
#  'a remake of the 1951 classic science fiction film about an alien visitor and his giant robot counterpart who visit earth.',
#  'after an alaskan town is plunged into darkness for a month, it is attacked by a bloodthirsty gang of vampires.',
#  'alexander, the king of macedonia and one of the greatest military leaders in the history of warfare, conquers much of the known world.',
#  'bound by a shared destiny, a teen bursting with scientific curiosity and a former boy-genius inventor embark on a mission to unearth the secrets of a place somewhere in time and space that exists in their collective memory.',
#  'a malfunctioning time machine at a ski resort takes a man back to 1986 with his two friends and nephew, where they must relive a fateful night and not change anything to make sure the nephew is born.',
#  "planet spaceballs' president skroob sends lord dark helmet to steal planet druidia's abundant supply of air to replenish their own, and only lone starr can stop them.",
#  'snow white, pursued by a jealous queen, hides with the dwarfs; the queen soon learns of this and prepares to feed her a poison apple.',
#  "robert ford, who's idolized jesse james since childhood, tries hard to join the reforming gang of the missouri outlaw, but gradually becomes resentful of the bandit leader.",
#  "the story of a family in waco, texas in 1956. the eldest son witnesses the loss of innocence and struggles with his parents' conflicting teachings.",
#  'after his master dies, a peasant squire, fueled by his desire for food and glory, creates a new identity for himself as a knight.',
#  'fresh from prison, a street racer who was framed by a wealthy business associate joins a cross country race with revenge in mind. his ex-partner, learning of the plan, places a massive bounty on his head as the race begins.',
#  "an unemployed single mother becomes a legal assistant and almost single-handedly brings down a california power company accused of polluting a city's water supply.",
#  'theseus is a mortal man chosen by zeus to lead the fight against the ruthless king hyperion, who is on a rampage across greece to obtain a weapon that can destroy humanity.',
#  "a man brutally murdered comes back to life as an undead avenger of his and his fiancée's murder.",
#  'two young boys encounter a fugitive and form a pact to help him evade the vigilantes that are on his trail and to reunite him with his true love.',
#  'in the aftermath of the persian gulf war, four soldiers set out to steal gold that was stolen from kuwait, but they discover people who desperately need their help.',
#  "the story of harvey milk, and his struggles as an american gay activist who fought for gay rights and became california's first openly gay elected official.",
#  'a rare book dealer, while seeking out the last two copies of a demon text, gets drawn into a conspiracy with supernatural overtones.',
#  'a young couple take in their two nieces only to suspect that a foreboding evil has latched itself to their family.',
#  'the extracurricular king of rushmore preparatory school is put on academic probation.',
#  'a young thief, seeking revenge for the death of his brother, is trained by the once great, but aged zorro, who also pursues vengeance of his own.',
#  'elle woods, a fashionable sorority queen is dumped by her boyfriend. she decides to follow him to law school, while she is there she figures out that there is more to her than just looks.',
#  'dave is a married man with three kids and a loving wife, and mitch is a single man who is at the prime of his sexual life. one fateful night while mitch and dave are peeing in a fountain, lightning strikes and they switch bodies.',
#  'the group nwa emerges from the mean streets of compton in los angeles, california, in the mid-1980s and revolutionizes hip hop culture with their music and tales about life in the hood.',
#  'while still out to destroy the evil umbrella corporation, alice joins a group of survivors living in a prison surrounded by the infected who also want to relocate to the mysterious but supposedly unharmed safe haven known only as arcadia.',
#  'blade, now a wanted man by the fbi, must join forces with the nightstalkers to face his most challenging enemy yet: dracula.',
#  'into the world of the emperor penguins, who find their soul mates through song, a penguin is born who cannot sing. but he can tap dance something fierce!',
#  'popular broadway actor gary johnston is recruited by the elite counter-terrorism organization team america: world police. as the world begins to crumble around him, he must battle with terrorists, celebrities and falling in love.',
#  'an impromptu goodbye party for professor john oldman becomes a mysterious interrogation after the retiring scholar reveals to his colleagues he has a longer and stranger past than they can imagine.',
#  'in the post-apocalyptic australian wasteland, a cynical drifter agrees to help a small, gasoline rich, community escape a band of bandits.',
#  'unless a comet can be destroyed before colliding with earth, only those allowed into shelters will survive. which people will survive?',
#  'an uptight fbi special agent is paired with a foul-mouthed boston cop to take down a ruthless drug lord.',
#  "following the death of his father, britt reid, heir to his father's large company, teams up with his late dad's assistant kato to become a masked crime fighting team.",
#  'security guard larry daley infiltrates the smithsonian institution in order to rescue jedediah and octavius, who have been shipped to the museum by mistake.',
#  'a successful cocaine dealer gets two tough assignments from his boss on the eve of his planned early retirement.',
#  'when a son of a gangster shark boss is accidentally killed while on the hunt, his would-be prey and his vegetarian brother both decide to use the incident to their own advantage.',
#  "charlie receives a golden ticket to a factory, his sweet tooth wants going into the lushing candy, it turns out there's an adventure in everything.",
#  "with the '70s behind him, san diego's top-rated newsman, ron burgundy, returns to take new york's first 24-hour news channel by storm.",
#  'lorraine and ed warren travel to north london to help a single mother raising four children alone in a house plagued by a malicious spirit.',
#  'a law firm brings in its ""fixer"" to remedy the situation after a lawyer has a breakdown while representing a chemical company that he knows is guilty in a multibillion-dollar class action suit.',
#  'a research chemist comes under personal and professional attack when he decides to appear in a ""60 minutes"" expose on big tobacco.',
#  'a television reporter and cameraman follow emergency workers into a dark apartment building and are quickly locked inside with something terrifying.',
#  'four college buddies embark on a road trip to retrieve an illicit tape mistakenly mailed to a female friend.',
#  'emperor kuzco is turned into a llama by his ex-administrator yzma, and must now regain his throne with the help of pacha, the gentle llama herder.',
#  'a civilian diving team is enlisted to search for a lost nuclear submarine and face danger while encountering an alien aquatic species.',
#  "newlywed couple ted and tami-lynn want to have a baby, but in order to qualify to be a parent, ted will have to prove he's a person in a court of law.",
#  'a ghostwriter hired to complete the memoirs of a former british prime minister uncovers secrets that put his own life in jeopardy.',
#  "#1 nascar driver ricky bobby stays atop the heap thanks to a pact with his best friend and teammate, cal naughton, jr. but when a french formula one driver, makes his way up the ladder, ricky bobby's talent and devotion are put to the test.",
#  'a young woman is followed by an unknown supernatural force after a sexual encounter.',
#  'an unusually intense storm pattern catches some commercial fishermen unaware and puts them in mortal danger.',
#  'the baltimore-set movie of interconnecting story arcs deals with the challenges of reading or misreading human behavior.',
#  'barney augments his team with new blood for a personal battle: to take down conrad stonebanks, the expendables co-founder and notorious arms trader who is hell bent on wiping out barney and every single one of his associates.',
#  'an adaptation of the fairy tale about a monstrous-looking prince and a young woman who fall in love.',
#  'a martial arts master agrees to teach karate to a bullied teenager.',
#  'the defiant leader moses rises up against the egyptian pharaoh ramses, setting 600,000 slaves on a monumental journey of escape from egypt and its terrifying cycle of deadly plagues.',
#  "a teenage girl raids a man's home in order to expose him under suspicion that he is a sex offender with pedophilia.",
#  'two sisters find their already strained relationship challenged as a mysterious new planet threatens to collide with earth.',
#  'affable hillbillies tucker and dale are on vacation at their dilapidated mountain cabin when they are mistaken for murderers by a group of preppy college students.',
#  'prison inmates form a football team to challenge the prison guards.',
#  'the story of the battle of iwo jima between the united states and imperial japan during world war ii, as told from the perspective of the japanese who fought it.',
#  'a young boy befriends a giant robot from outer space that a paranoid government agent wants to destroy.',
#  'a suburban american family is being stalked by a group of psychotic people who live in the desert, far away from civilization.',
#  'a man is accidentally transported to 1300 a.d., where he must battle an army of the dead and retrieve the necronomicon so he can return home.',
#  "in the summer of 1987, a college graduate takes a 'nowhere' job at his local amusement park, only to find it's the perfect course to get him prepared for the real world.",
#  'the true story of whitey bulger, the brother of a state senator and the most infamous violent criminal in the history of south boston, who became an fbi informant to take down a mafia family invading his turf.',
#  "in 2002, two rival olympic ice skaters were stripped of their gold medals and permanently banned from men's single competition. presently, however, they've found a loophole that will allow them to qualify as a pairs team.",
#  'a convicted rapist, released from prison after serving a fourteen-year sentence, stalks the family of the lawyer who originally defended him.',
#  'hitman ""el mariachi"" becomes involved in international espionage involving a psychotic cia agent and a corrupt mexican general.',
#  'a freewheeling detroit cop pursuing a murder investigation finds himself dealing with the very different culture of beverly hills.',
#  'the two best hired guns in the west must save president grant from the clutches of a nineteenth-century inventor-villain.',
#  'martin riggs and roger murtaugh pursue an arms dealer who is a former lapd officer.',
#  'retired c.i.a. agent frank moses reunites his unlikely team of elite operatives for a global quest to track down a missing portable nuclear device.',
#  'abraham lincoln, the 16th president of the united states, discovers vampires are planning to take over the united states. he makes it his mission to eliminate them.',
#  'a political consultant tries to explain his impending divorce and past relationships to his 11-year-old daughter.',
#  'a scheming raccoon fools a mismatched family of forest creatures into helping him repay a debt of food, by invading the new suburban sprawl that popped up while they were hibernating...and learns a lesson about family himself.',
#  'five friends head to a remote cabin, where the discovery of a book of the dead leads them to unwittingly summon up demons living in the nearby woods.',
#  'with personal crises and age weighing in on them, lapd officers riggs and murtaugh must contend with a deadly chinese crimelord trying to get his brother out of prison.',
#  "an alien orphan is sent from his dying planet to earth, where he grows up to become his adoptive home's first and greatest superhero.",
#  "in new york city, a case of mistaken identity turns a bored married couple's attempt at a glamorous and romantic evening into something more thrilling and dangerous.",
#  "based on writer susanna kaysen's account of her 18-month stay at a mental hospital in the 1960s.",
#  "a rich high school student tries to boost a new pupil's popularity, but reckons without affairs of the heart getting in the way.",
#  "the comic 'bluntman and chronic' is based on real-life stoners jay and silent bob, so when they get no profit from a big-screen adaptation they set out to wreck the movie.",
#  'the cruel king louis xiv of france has a secret twin brother who he keeps imprisoned. can the twin be substituted for the real king?',
#  "left for dead on a sun-scorched planet, riddick finds himself up against an alien race of predators. activating an emergency beacon alerts two ships: one carrying a new breed of mercenary, the other captained by a man from riddick's past.",
#  'a bereaved woman and her daughter are flying home from berlin to america. at 30,000 feet, the child vanishes, and nobody will admit she was ever on the plane.',
#  'after refusing to attack an enemy position, a general accuses the soldiers of cowardice and their commanding officer must defend them.',
#  'a young boy embarks on a magical adventure to the north pole on the polar express. during his adventure he learns about friendship, bravery, and the spirit of christmas.',
#  'the attempted assassination of the american president is told and re-told from several different perspectives.',
#  'when the evil spirit pitch launches an assault on earth, the immortal guardians team up to protect the innocence of children all around the world.',
#  ...]

# %% [markdown]
# Para construir el bag of words vamos a utilizar la clase de *scikit-learn* [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) y la aplicamos a los plots que tenemos usando *fit_transform*. Podemos ver que palabras ha usado en la bolsa de palabras usando *get_feature_names*.

# %%
vectorizer = CountVectorizer(min_df=0.001,
                     max_df=0.5,
                     max_features=1000,stop_words=STOP_WORDS)

bowmovie_matrix = vectorizer.fit_transform(plots_clean) # <<RELLENAR: construir usando fit_transform>>
pprint(vectorizer.get_feature_names())
# Out:
# C:\Users\usuario\Anaconda3\envs\practica16\lib\site-packages\sklearn\feature_extraction\text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# ['000',
#  '10',
#  '12',
#  '15',
#  '1950s',
#  '1960s',
#  '1970s',
#  'abandoned',
#  'ability',
#  'accident',
#  'accidentally',
#  'account',
#  'accused',
#  'act',
#  'action',
#  'actor',
#  'actress',
#  'actually',
#  'adaptation',
#  'adult',
#  'adventure',
#  'adventures',
#  'affair',
#  'african',
#  'age',
#  'aged',
#  'agent',
#  'agents',
#  'aging',
#  'ago',
#  'agrees',
#  'air',
#  'alien',
#  'aliens',
#  'alive',
#  'america',
#  'american',
#  'ancient',
#  'angeles',
#  'animal',
#  'animals',
#  'apart',
#  'apartment',
#  'area',
#  'armed',
#  'arms',
#  'army',
#  'arrival',
#  'arrives',
#  'art',
#  'artist',
#  'arts',
#  'aspiring',
#  'assassin',
#  'assassination',
#  'assigned',
#  'assistant',
#  'attack',
#  'attempt',
#  'attempts',
#  'author',
#  'avenge',
#  'away',
#  'awry',
#  'baby',
#  'bad',
#  'band',
#  'bank',
#  'bar',
#  'baseball',
#  'based',
#  'basketball',
#  'battle',
#  'beach',
#  'bear',
#  'beautiful',
#  'befriends',
#  'begin',
#  'begins',
#  'believe',
#  'believes',
#  'beloved',
#  'best',
#  'better',
#  'big',
#  'biggest',
#  'birthday',
#  'bizarre',
#  'black',
#  'blood',
#  'body',
#  'bond',
#  'book',
#  'border',
#  'born',
#  'boss',
#  'bounty',
#  'boy',
#  'boyfriend',
#  'boys',
#  'break',
#  'breaks',
#  'bride',
#  'bring',
#  'brings',
#  'britain',
#  'british',
#  'brother',
#  'brothers',
#  'brought',
#  'brutal',
#  'build',
#  'building',
#  'business',
#  'businessman',
#  'cabin',
#  'california',
#  'called',
#  'camp',
#  'cancer',
#  'captain',
#  'captured',
#  'car',
#  'care',
#  'career',
#  'case',
#  'casino',
#  'cat',
#  'catholic',
#  'caught',
#  'cause',
#  'causes',
#  'center',
#  'centered',
#  'century',
#  'challenge',
#  'champion',
#  'chance',
#  'change',
#  'changes',
#  'chaos',
#  'character',
#  'characters',
#  'charlie',
#  'chicago',
#  'child',
#  'childhood',
#  'children',
#  'china',
#  'chinese',
#  'christmas',
#  'church',
#  'cia',
#  'city',
#  'civil',
#  'claims',
#  'class',
#  'classic',
#  'close',
#  'club',
#  'co',
#  'coach',
#  'cold',
#  'college',
#  'come',
#  'comedy',
#  'comes',
#  'comic',
#  'coming',
#  'commit',
#  'committed',
#  'community',
#  'company',
#  'compete',
#  'competition',
#  'complete',
#  'complicated',
#  'computer',
#  'con',
#  'concert',
#  'conflict',
#  'confront',
#  'connection',
#  'consequences',
#  'conspiracy',
#  'control',
#  'cop',
#  'cops',
#  'corporate',
#  'corporation',
#  'corrupt',
#  'corruption',
#  'country',
#  'couple',
#  'course',
#  'cover',
#  'crash',
#  'creates',
#  'creatures',
#  'crew',
#  'crime',
#  'criminal',
#  'criminals',
#  'crisis',
#  'cross',
#  'curse',
#  'dance',
#  'dancer',
#  'danger',
#  'dangerous',
#  'dark',
#  'date',
#  'daughter',
#  'day',
#  'days',
#  'dead',
#  'deadly',
#  'deal',
#  'dealer',
#  'dealing',
#  'death',
#  'decades',
#  'deceased',
#  'decide',
#  'decides',
#  'deep',
#  'defeat',
#  'defend',
#  'desert',
#  'desire',
#  'desperate',
#  'despite',
#  'destroy',
#  'destroying',
#  'detective',
#  'determined',
#  'develops',
#  'dies',
#  'different',
#  'difficult',
#  'director',
#  'disappearance',
#  'discover',
#  'discovers',
#  'discovery',
#  'divorce',
#  'divorced',
#  'doctor',
#  'documentary',
#  'doesn',
#  'dog',
#  'don',
#  'door',
#  'double',
#  'dr',
#  'dragon',
#  'drama',
#  'drawn',
#  'dream',
#  'dreams',
#  'driver',
#  'drug',
#  'drugs',
#  'dying',
#  'early',
#  'earth',
#  'east',
#  'eccentric',
#  'effort',
#  'elite',
#  'embark',
#  'embarks',
#  'empire',
#  'encounter',
#  'encounters',
#  'end',
#  'ends',
#  'enemy',
#  'england',
#  'english',
#  'enlists',
#  'enter',
#  'enters',
#  'entire',
#  'epic',
#  'era',
#  'escape',
#  'escaped',
#  'escapes',
#  'estate',
#  'estranged',
#  'europe',
#  'eve',
#  'event',
#  'events',
#  'eventually',
#  'evil',
#  'ex',
#  'executive',
#  'experience',
#  'experiences',
#  'experiment',
#  'extraordinary',
#  'face',
#  'faced',
#  'faces',
#  'failed',
#  'fall',
#  'falling',
#  'falls',
#  'fame',
#  'families',
#  'family',
#  'famous',
#  'fantasy',
#  'far',
#  'farm',
#  'fast',
#  'fate',
#  'father',
#  'fbi',
#  'fellow',
#  'female',
#  'fight',
#  'fighter',
#  'fighting',
#  'fights',
#  'figure',
#  'film',
#  'filmmaker',
#  'final',
#  'finally',
#  'find',
#  'finding',
#  'finds',
#  'florida',
#  'follow',
#  'following',
#  'follows',
#  'food',
#  'football',
#  'force',
#  'forced',
#  'forces',
#  'forever',
#  'form',
#  'forms',
#  'foster',
#  'found',
#  'france',
#  'francisco',
#  'frank',
#  'free',
#  'freedom',
#  'french',
#  'friend',
#  'friends',
#  'friendship',
#  'frustrated',
#  'future',
#  'game',
#  'games',
#  'gang',
#  'gangster',
#  'gangsters',
#  'gay',
#  'general',
#  'genius',
#  'george',
#  'german',
#  'germany',
#  'gets',
#  'getting',
#  'giant',
#  'girl',
#  'girlfriend',
#  'girls',
#  'given',
#  'gives',
#  'global',
#  'god',
#  'goes',
#  'going',
#  'gold',
#  'gone',
#  'good',
#  'government',
#  'great',
#  'greatest',
#  'group',
#  'growing',
#  'grows',
#  'guard',
#  'gun',
#  'guy',
#  'half',
#  'hands',
#  'happens',
#  'hard',
#  'harry',
#  'haunted',
#  'having',
#  'head',
#  'heads',
#  'heart',
#  'heist',
#  'held',
#  'hell',
#  'help',
#  'helped',
#  'helps',
#  'henry',
#  'hero',
#  'hidden',
#  'high',
#  'hire',
#  'hired',
#  'history',
#  'hit',
#  'holds',
#  'holiday',
#  'hollywood',
#  'home',
#  'hometown',
#  'homicide',
#  'hope',
#  'hopes',
#  'horrific',
#  'horror',
#  'horse',
#  'hospital',
#  'host',
#  'hostage',
#  'hot',
#  'hotel',
#  'house',
#  'human',
#  'humanity',
#  'humans',
#  'hunt',
#  'hunter',
#  'husband',
#  'idea',
#  'identity',
#  'ii',
#  'ill',
#  'important',
#  'imprisoned',
#  'inadvertently',
#  'including',
#  'increasingly',
#  'india',
#  'indian',
#  'industry',
#  'inner',
#  'innocent',
#  'insane',
#  'inside',
#  'inspired',
#  'instead',
#  'intelligence',
#  'international',
#  'invasion',
#  'investigate',
#  'investigates',
#  'investigation',
#  'involved',
#  'involving',
#  'irish',
#  'island',
#  'isolated',
#  'italian',
#  'italy',
#  'jack',
#  'james',
#  'jewish',
#  'job',
#  'john',
#  'join',
#  'joins',
#  'jones',
#  'journalist',
#  'journey',
#  'justice',
#  'kid',
#  'kidnapped',
#  'kidnapping',
#  'kids',
#  'kill',
#  'killed',
#  'killer',
#  'killing',
#  'king',
#  'kingdom',
#  'know',
#  'known',
#  'knows',
#  'lake',
#  'land',
#  'lands',
#  'large',
#  'las',
#  'late',
#  'later',
#  'latest',
#  'law',
#  'lawyer',
#  'lead',
#  'leader',
#  'leading',
#  'leads',
#  'league',
#  'learn',
#  'learns',
#  'leave',
#  'leaves',
#  'led',
#  'lee',
#  'left',
#  'legend',
#  'legendary',
#  'life',
#  'like',
#  'line',
#  'little',
#  'live',
#  'lives',
#  'living',
#  'local',
#  'london',
#  'lonely',
#  'long',
#  'look',
#  'looking',
#  'looks',
#  'lord',
#  'los',
#  'lose',
#  'loses',
#  'losing',
#  'loss',
#  'lost',
#  'love',
#  'lover',
#  'loves',
#  'loving',
#  'luke',
#  'machine',
#  'mad',
#  'mafia',
#  'magic',
#  'magical',
#  'major',
#  'makes',
#  'making',
#  'male',
#  'man',
#  'manager',
#  'marine',
#  'marriage',
#  'married',
#  'martial',
#  'martin',
#  'master',
#  'media',
#  'medical',
#  'meet',
#  'meets',
#  'member',
#  'members',
#  'memories',
#  'memory',
#  'men',
#  'mexican',
#  'mexico',
#  'michael',
#  'mid',
#  'middle',
#  'midst',
#  'military',
#  'million',
#  'millions',
#  'mind',
#  'missing',
#  'mission',
#  'mistaken',
#  'mob',
#  'modern',
#  'mom',
#  'money',
#  'monster',
#  'monsters',
#  'mother',
#  'mountain',
#  'moves',
#  'movie',
#  'moving',
#  'mr',
#  'mumbai',
#  'murder',
#  'murdered',
#  'murders',
#  'music',
#  'musical',
#  'musician',
#  'mysterious',
#  'mystery',
#  'naive',
#  'named',
#  'nation',
#  'national',
#  'nazi',
#  'near',
#  'nearly',
#  'need',
#  'needs',
#  'neighborhood',
#  'new',
#  'newly',
#  'night',
#  'north',
#  'notorious',
#  'novel',
#  'nuclear',
#  'number',
#  'nurse',
#  'obsession',
#  'ocean',
#  'officer',
#  'oil',
#  'old',
#  'older',
#  'open',
#  'operative',
#  'opportunity',
#  'order',
#  'organization',
#  'outlaw',
#  'outside',
#  'owner',
#  'pair',
#  'parents',
#  'paris',
#  'park',
#  'partner',
#  'party',
#  'past',
#  'path',
#  'peace',
#  'people',
#  'perfect',
#  'person',
#  'personal',
#  'peter',
#  'pilot',
#  'place',
#  'plan',
#  'plane',
#  'planet',
#  'plans',
#  'play',
#  'player',
#  'playing',
#  'plays',
#  'plot',
#  'police',
#  'policeman',
#  'political',
#  'poor',
#  'popular',
#  'post',
#  'power',
#  'powerful',
#  'powers',
#  'pregnant',
#  'president',
#  'prevent',
#  'priest',
#  'prince',
#  'princess',
#  'prison',
#  'private',
#  'problems',
#  'process',
#  'producer',
#  'professional',
#  'professor',
#  'program',
#  'project',
#  'protect',
#  'prove',
#  'psychiatrist',
#  'psychic',
#  'pull',
#  'pursued',
#  'puts',
#  'queen',
#  'quest',
#  'questions',
#  'quiet',
#  'race',
#  'radio',
#  'raised',
#  'ray',
#  'real',
#  'reality',
#  'realize',
#  'realizes',
#  'receives',
#  'recently',
#  'recover',
#  'recruited',
#  'recruits',
#  'red',
#  'redemption',
#  'relationship',
#  'relationships',
#  'released',
#  'religious',
#  'remote',
#  'reporter',
#  'rescue',
#  'research',
#  'residents',
#  'resort',
#  'responsible',
#  'rest',
#  'results',
#  'retired',
#  'retirement',
#  'retrieve',
#  'return',
#  'returns',
#  'reunion',
#  'reunite',
#  'revenge',
#  'rich',
#  'right',
#  'rights',
#  'ring',
#  'rise',
#  'rising',
#  'rival',
#  'road',
#  'rob',
#  'robert',
#  'rock',
#  'rogue',
#  'role',
#  'roman',
#  'romance',
#  'romantic',
#  'room',
#  'rule',
#  'run',
#  'runs',
#  'rural',
#  'russian',
#  'ruthless',
#  'safe',
#  'san',
#  'save',
#  'scheme',
#  'school',
#  'scientist',
#  'sea',
#  'search',
#  'searches',
#  'searching',
#  'season',
#  'second',
#  'secret',
#  'secrets',
#  'security',
#  'seek',
#  'seeking',
#  'seeks',
#  'seemingly',
#  'sees',
#  'self',
#  'senior',
#  'sent',
#  'serial',
#  'series',
#  'service',
#  'set',
#  'sets',
#  'seven',
#  'sex',
#  'sexual',
#  'share',
#  'sheriff',
#  'ship',
#  'short',
#  'shot',
#  'shy',
#  'simple',
#  'singer',
#  'single',
#  'sinister',
#  'sister',
#  'sisters',
#  'situation',
#  'skills',
#  'slowly',
#  'small',
#  'social',
#  'society',
#  'soldier',
#  'soldiers',
#  'son',
#  'sons',
#  'soon',
#  'soul',
#  'south',
#  'southern',
#  'space',
#  'special',
#  'spend',
#  'spirit',
#  'spy',
#  'squad',
#  'stage',
#  'stand',
#  'star',
#  'start',
#  'starts',
#  'state',
#  'states',
#  'station',
#  'stay',
#  'steal',
#  'stolen',
#  'stop',
#  'stories',
#  'storm',
#  'story',
#  'stranded',
#  'strange',
#  'stranger',
#  'strangers',
#  'street',
#  'streets',
#  'struggle',
#  'struggles',
#  'struggling',
#  'student',
#  'students',
#  'stumbles',
#  'suburban',
#  'success',
#  'successful',
#  'suddenly',
#  'suffering',
#  'suicide',
#  'summer',
#  'super',
#  'superhero',
#  'supernatural',
#  'survival',
#  'survive',
#  'survivors',
#  'suspect',
#  'suspects',
#  'system',
#  'taken',
#  'takes',
#  'taking',
#  'tale',
#  'talented',
#  'tales',
#  'talking',
#  'target',
#  'teacher',
#  'team',
#  'teams',
#  'teen',
#  'teenage',
#  'teenager',
#  'teenagers',
#  'teens',
#  'television',
#  'tells',
#  'terrible',
#  'terrifying',
#  'terror',
#  'terrorist',
#  'terrorists',
#  'test',
#  'texas',
#  'thief',
#  'things',
#  'thomas',
#  'threat',
#  'threatened',
#  'threatens',
#  'thriller',
#  'time',
#  'told',
#  'torn',
#  'tough',
#  'tour',
#  'town',
#  'track',
#  'tragedy',
#  'tragic',
#  'train',
#  'trained',
#  'training',
#  'trapped',
#  'travel',
#  'traveling',
#  'travels',
#  'treasure',
#  'trial',
#  'tries',
#  'trio',
#  'trip',
#  'trouble',
#  'troubled',
#  'true',
#  'truth',
#  'try',
#  'trying',
#  'turn',
#  'turned',
#  'turns',
#  'tv',
#  'twin',
#  'ultimate',
#  'uncle',
#  'uncover',
#  'undercover',
#  'underground',
#  'unexpected',
#  'union',
#  'unique',
#  'unit',
#  'united',
#  'university',
#  'unknown',
#  'unlikely',
#  'unusual',
#  'upside',
#  'use',
#  'uses',
#  'vacation',
#  'vampire',
#  'vampires',
#  've',
#  'vegas',
#  'vengeance',
#  'vengeful',
#  'veteran',
#  'victim',
#  'video',
#  'vietnam',
#  'village',
#  'violence',
#  'violent',
#  'visit',
#  'wake',
#  'wakes',
#  'want',
#  'wants',
#  'war',
#  'warrior',
#  'warriors',
#  'water',
#  'way',
#  'ways',
#  'wealthy',
#  'weapon',
#  'wedding',
#  'weekend',
#  'west',
#  'white',
#  'widow',
#  'wife',
#  'wild',
#  'win',
#  'witch',
#  'witness',
#  'woman',
#  'women',
#  'woods',
#  'work',
#  'worker',
#  'working',
#  'works',
#  'world',
#  'writer',
#  'wrong',
#  'wwii',
#  'year',
#  'years',
#  'york',
#  'young',
#  'younger',
#  'youth']

# %% [markdown]
# Si usamos esta nueva matrix de datos ¿Qué 10 películas recomendaría al usuario 1 y al usuario 2?

# %%
recommendations1 = get_content_based_recommendation(df,bowmovie_matrix,user_profile1,topk=10) # <<RELLENAR: Recomendador basado en bolsa de palabras, usuario 1>>
display('User 1')
display(df.iloc[recommendations1][["Title","imdbRating"]])
recommendations2 = get_content_based_recommendation(df,bowmovie_matrix,user_profile2,topk=10)# <<RELLENAR: Recomendador basado en bolsa de palabras, usuario 2>>
display('User 2')
display(df.iloc[recommendations2][["Title","imdbRating"]])
# Out:
# 'User 1'
#                                    Title  imdbRating
# 308                            Stalag 17         8.0
# 105                     Schindler's List         8.9
# 4812                   Sands of Iwo Jima         7.2
# 4844               Taxi to the Dark Side         7.6
# 3209                 Crocodile Dundee II         5.5
# 4882             My Last Day Without You         5.7
# 2062                  Lion of the Desert         8.4
# 3381  Tales from the Crypt: Demon Knight         6.7
# 2929                     The Railway Man         7.1
# 4805                          Hellraiser         7.0
# 'User 2'
#                        Title  imdbRating
# 493   Hum Dil De Chuke Sanam         7.6
# 3506          She's All That         5.8
# 4647                   Vaalu         5.0
# 1262         You've Got Mail         6.6
# 2649      The Rage: Carrie 2         4.6
# 3900           Les visiteurs         7.0
# 3921      Dazed and Confused         7.7
# 576      Rab Ne Bana Di Jodi         7.2
# 4119                  Saved!         6.9
# 3757                  Easy A         7.1

# %% [markdown]
# Para esta siguiente parte vamos a cargar el modelo mediano de spacy para obtener los vectores word2vec de cada palabra de los argumentos. Si no lo teneis descargado se puede hacer en una consola como que tenga python como *python -m spacy download en_core_web_lg*, es casi 1 GB el modelo por lo que tardará un rato. Posteriormente cargamos el modelo spacy, puede tardar un poco también.

# %%
nlp_analyzer = spacy.load("en_core_web_lg")
# Out:
# C:\Users\usuario\Anaconda3\envs\practica16\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_core_web_lg' (2.2.5) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.2). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# Ahora lo usaremos para analizar la lista de descripciones que tenemos, para ello usaremos la función pipe que aplica el modelo de spacy a una lista de textos y construiremos un array con el vector de cada argumento.

# %%
plot_documents = list(nlp_analyzer.pipe(plots_clean))

# Construir una matrix con el promedio de vectores de cada palabra si no es una stopword
vector_matrix = np.zeros((len(plots_clean),300))
for idx, doc_ in enumerate(plot_documents):
    vector_matrix[idx,:]  =  sum([tok.vector for tok in doc_ if not tok.is_stop])/len(doc_)

# %% [markdown]
# Si usamos esta nueva matrix de datos ¿Qué 10 películas recomendaría al usuario 1 y al usuario 2? ¿Qué creéis que marca la diferencia entre la representación basada en bolsas de palabras y esta?

# %%
recommendations1 = get_content_based_recommendation(df,vector_matrix,user_profile1,topk=10)# <<RELLENAR: Recomendador basado en word2vec, usuario 1>>
display('User 1')
display(df.iloc[recommendations1][["Title","imdbRating"]])
recommendations2 = get_content_based_recommendation(df,vector_matrix,user_profile2,topk=10)# <<RELLENAR: Recomendador basado en word2vec, usuario 2>>
display('User 2')
display(df.iloc[recommendations2][["Title","imdbRating"]])
# Out:
# 'User 1'
#                      Title  imdbRating
# 4928   Saints and Soldiers         6.8
# 1669     The Bounty Hunter         5.5
# 2929       The Railway Man         7.1
# 643          The 400 Blows         8.1
# 1487         Elizabethtown         6.4
# 178   Inglourious Basterds         8.3
# 2250    An Unfinished Life         7.0
# 1078       Just Go with It         6.4
# 1788       I Love You, Man         7.0
# 570             Dhobi Ghat         7.1
# 'User 2'
#                             Title  imdbRating
# 1533         Crazy, Stupid, Love.         7.4
# 3892  We Need to Talk About Kevin         7.5
# 3164                    Post Grad         5.3
# 1679          Kicking & Screaming         5.6
# 2241                  Wicker Park         7.0
# 3106   The Object of My Affection         6.0
# 4566                     Thirteen         6.8
# 618                      The Hunt         8.3
# 541               Namastey London         7.3
# 489                  Socha Na Tha         7.6

# %% [markdown]
# En estos casos se recomiendan peliculas diferentes.
#
# Para un recomendador basado en el argumento es importante realizar un análisis semántico de las peliculas, dado que su descripción puede ser fundamental para definir el gusto de una persona y no solo el genero de la pelicula. Las recomendaciones realizadas con la bolsa de palabras tiene ciertos problemas como la perdida de noción de similitud, no hay significado de la palabra ni contexto o significado de la frase, por lo que esta recomendación puede ser sesgada bajo ciertos parametros. La recomendación realizada con word2vec permite un análisis un poco más amplio dado que se puede dar una interpretación semántica aunque sigue siendo limitada.
#
# Estas recomendaciones ya no se basan en el promedio de puntaje dado, toman una descripción de la pelicula para darle al usuario una recomedación personalizada que le permitirá encontrar con mayor facilidad contenido que sea de su agrado.

# %% [markdown]
# ### TAREA 4. Recomendador basado en el argumento y en Deep Learning.
# En esta parte haremos lo mismo que en la sección anterior pero usando BERT para crear los vectores que representan cada párrafo. Usaremos los modelos preentrenados de BERT que mantiene HuggingFace y que están integrados con spacy. Para instalarlo usaremos un comando parecido al anterior *python -m spacy download en_trf_bertbaseuncased_lg*. Teneis más información en el [blog de explosion.ai](https://explosion.ai/blog/spacy-transformers). La forma de cargar los vectores es igual que la usada en el apartado anterior.

# %%
nlp_analyzer_bert = spacy.load("en_trf_bertbaseuncased_lg")

# %%
# <<RELLENAR: construir la matrix bert_matrix de forma similar al vector_matrix anterior>>
plot_documents = list(nlp_analyzer_bert.pipe(plots_clean))
bert_matrix = np.zeros((len(plots_clean),768))
for idx, doc_ in enumerate(plot_documents):
    bert_matrix[idx,:]  =  sum([tok.vector for tok in doc_ if not tok.is_stop])/len(doc_)

# %% [markdown]
# ¿Qué películas recomendaría al usuario 1 y al usuario 2 con cada aproximación? ¿Qué creéis que marca la diferencia entre esta representación y las anteriores? ¿Creéis que mejora?

# %%
recommendations1 = get_content_based_recommendation(df,bert_matrix,user_profile1,topk=10) # <<RELLENAR: Recomendador basado en BERT, usuario 1>>
display('User 1')
display(df.iloc[recommendations1][["Title","imdbRating"]])

recommendations2 = get_content_based_recommendation(df,bert_matrix,user_profile2,topk=10) # <<RELLENAR: Recomendador basado en BERT, usuario 2>>
display('User 2')
display(df.iloc[recommendations2][["Title","imdbRating"]])
# Out:
# 'User 1'
#                           Title  imdbRating
# 3328               True Romance         8.0
# 677              Jurassic World         7.0
# 1078            Just Go with It         6.4
# 1908     Star Trek: Generations         6.6
# 2067        Black Water Transit         7.1
# 871   The Chronicles of Riddick         6.7
# 5135       A Fistful of Dollars         8.0
# 3748                      Limbo         7.1
# 3241            Little Children         7.6
# 325      The Philadelphia Story         8.0
# 'User 2'
#                            Title  imdbRating
# 283        Cat on a Hot Tin Roof         8.1
# 1533        Crazy, Stupid, Love.         7.4
# 967                  Seventh Son         5.5
# 3876                  Alien Zone         4.1
# 4085            The Way Way Back         7.4
# 3227          My Boss's Daughter         4.6
# 3665              American Heist         5.2
# 1027            It's Complicated         6.6
# 3042  Things We Lost in the Fire         7.2
# 792   How to Train Your Dragon 2         7.9

# %% [markdown]
# Todos los resultados son diferentes y es de esperarse debido a que se usan diferentes modelos para calcular el Top 10 de peliculas.
#
# BERT es un modelo más robusto, con mayor cantidad de datos y palabras almacenadas lo que permite realizar un análisis a profundidad comparado con word2vec y la bolsa de palabras, con el fin de encontrar una similitud más cercana con las peliculas que el usuario ha visto previamente.

# %% [markdown]
# ## Parte opcional: Recomendación basada en filtado colaborativo.
#
# La base de datos propuesta no permite el uso de técnicas de filtado colaborativo, para el que lo desee hay un dataset llamado [MovieLens](https://movielens.org/) con información de puntuaciones de usuarios. Estas primeras celdas son para cargar los datos y reorganizarlos. Deberás descomprimir el fichero *movielens-20m-dataset.zip* en el directorio de trabajo.

# %%
import os
from scipy.sparse.linalg import svds

# %%
data_path = 'movielens-20m-dataset'
movies_filename = 'movie.csv'
ratings_filename = 'rating.csv'

df_movies = pd.read_csv( os.path.join(data_path, movies_filename), usecols=['movieId', 'title'], dtype={'movieId': 'int32', 'title': 'str'})

df_ratings = pd.read_csv( os.path.join(data_path, ratings_filename), usecols=['userId', 'movieId', 'rating'], dtype={'userId': 'int32', 'movieId': 'int32', 'rating': 'float32'})

# %%
display(df_movies.head(10))
display(df_ratings.head(10))
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5
# 5       1      112     3.5
# 6       1      151     4.0
# 7       1      223     4.0
# 8       1      253     4.0
# 9       1      260     4.0

# %% [markdown]
# Aquí vamos a crear la matriz de ratings y quitarle la media que luego usaremos como sesgo de usuario en la recomendación. Además definimos la función que a partir de los *ratings* estimados devuelve la lista de recomendaciones.

# %%
df_ratings=df_ratings[:2000000]
df_movie_features = df_ratings.pivot(index='userId', columns='movieId', values='rating').fillna(0)

R = df_movie_features.values
user_ratings_mean = np.mean(R, axis = 1)
R_demeaned = R - user_ratings_mean.reshape(-1, 1)

# %%
def recommend_movies(preds_df, userID, movies_df, original_ratings_df, num_recommendations=5):
    
    # Get and sort the user's predictions
    user_row_number = userID - 1 # UserID starts at 1, not 0
    sorted_user_predictions = preds_df.iloc[user_row_number].sort_values(ascending=False) # UserID starts at 1

    # Get the user's data and merge in the movie information.
    user_data = original_ratings_df[original_ratings_df.userId == (userID)]
    user_full = (user_data.merge(movies_df, how = 'left', left_on = 'movieId', right_on = 'movieId').
                     sort_values(['rating'], ascending=False)
                 )

    # Recommend the highest predicted rating movies that the user hasn't seen yet.
    recommendations = (movies_df[~movies_df['movieId'].isin(user_full['movieId'])]).merge(pd.DataFrame(sorted_user_predictions).reset_index(), how = 'left', left_on = 'movieId',
               right_on = 'movieId').rename(columns = {user_row_number: 'Predictions'}).sort_values('Predictions', ascending = False).iloc[:num_recommendations, :-1]
                      

    return user_full, recommendations

# %% [markdown]
# ### Entrenamiento
# Calcula usando la función svds la descomposición en valores singulares de la matriz *R_demeaned*. la descomposición SVD devuelve dos matrices U y Vt y un escalar sigma, en este orden: U, sigma, V^T. Para calcular las matrices A (usuario-concepto) y B (concepto-item) hay que convertir el escalar sigma en una matriz diagonal D, usando *np.diag* y aplicando la siguiente formula $A=U\cdot D$, el $\cdot$ se calcula con *np.dot*. La matrix B es directamente Vt. Usaremos el valor k=50 para el número de conceptos.

# %%
U, sigma, Vt = svds(R_demeaned,k=50)# <<RELLENAR: Calculo de la descomposición>>
Sigma = np.diag(sigma) # <<RELLENAR: Convertir en matrix diagonal>>
A = np.dot(U,Sigma) # <<RELLENAR >>
B = Vt # <<RELLENAR >>

R_hat = np.dot(A, B) + user_ratings_mean.reshape(-1, 1)

preds_df = pd.DataFrame(R_hat, columns = df_movie_features.columns)
preds_df.head()
# Out:
# movieId    1         2         3         4         5         6         7       \
# 0       -1.032377  0.816792  0.065367 -0.069286 -0.089829  0.488377 -0.417960
# 1        0.878419  0.018589  0.350089  0.069685  0.219143  0.379300  0.404332
# 2        2.004504  0.853211 -0.124891  0.033102 -0.197886  0.725844 -0.070364
# 3       -0.730047  0.575874  0.316375 -0.043769  0.175544  0.804843  0.024102
# 4        1.487834  1.324308  1.370971  0.112844  1.282827  0.726827  1.453524
#
# movieId    8         9         10      ...    130073    130075    130219  \
# 0        0.045866 -0.139050 -0.341772  ...  0.000436 -0.000913 -0.005743
# 1        0.008962  0.102663 -0.336462  ...  0.001779 -0.000374 -0.001408
# 2       -0.043637 -0.004803  0.117869  ...  0.003959 -0.004786 -0.001086
# 3        0.053929  0.182834  1.027777  ...  0.001220  0.001608  0.002619
# 4        0.217864  0.285134  1.278287  ... -0.000932 -0.001432 -0.000049
#
# movieId    130462    130490    130496    130512    130642    130644    130768
# 0       -0.006718 -0.004173 -0.002836 -0.009607 -0.006603 -0.001093 -0.002193
# 1        0.002510  0.002424 -0.000837 -0.004802  0.001166 -0.000476  0.000287
# 2        0.001811  0.005158  0.001003  0.019518 -0.001382 -0.001391  0.000514
# 3        0.001078  0.003182  0.001051  0.001691  0.001607  0.002382  0.001786
# 4        0.002574 -0.002193 -0.001840 -0.003786  0.001492  0.001600  0.001771
#
# [5 rows x 16715 columns]

# %% [markdown]
# ### Predicción:
# Vamos a recomendar 10 películas al usuario 200 usando la función *recommend_movies* definida arriba. Experimenta con otros usuarios y comenta los resultados.

# %%
already_rated, predictions = recommend_movies(preds_df, 200, df_movies, df_ratings, num_recommendations=10)# <<RELLENAR: Recomendador basado en filtrado colaborativo>>
already_rated.head(10)
# Out:
#     userId  movieId  rating                                              title
# 0      200        6     5.0                                        Heat (1995)
# 11     200      150     5.0                                   Apollo 13 (1995)
# 49     200      382     5.0                                        Wolf (1994)
# 38     200      353     5.0                                   Crow, The (1994)
# 59     200      509     5.0                                  Piano, The (1993)
# 60     200      520     5.0                   Robin Hood: Men in Tights (1993)
# 61     200      527     5.0                            Schindler's List (1993)
# 63     200      543     5.0                So I Married an Axe Murderer (1993)
# 30     200      296     5.0                                Pulp Fiction (1994)
# 27     200      273     5.0  Mary Shelley's Frankenstein (Frankenstein) (1994)

# %%
predictions
# Out:
#      movieId                                   title
# 39        47             Seven (a.k.a. Se7en) (1995)
# 257      288             Natural Born Killers (1994)
# 42        50              Usual Suspects, The (1995)
# 291      329           Star Trek: Generations (1994)
# 414      474              In the Line of Fire (1993)
# 163      185                         Net, The (1995)
# 356      410             Addams Family Values (1993)
# 445      508                     Philadelphia (1993)
# 483      551  Nightmare Before Christmas, The (1993)
# 365      420            Beverly Hills Cop III (1994)

# %%
already_rated, predictions = recommend_movies(preds_df, 156, df_movies, df_ratings, num_recommendations=10)# <<RELLENAR: Recomendador basado en filtrado colaborativo>>
already_rated.head(10)
# Out:
#      userId  movieId  rating                          title
# 0       156        1     5.0               Toy Story (1995)
# 749     156     2000     5.0           Lethal Weapon (1987)
# 707     156     1892     5.0       Perfect Murder, A (1998)
# 729     156     1951     5.0                 Oliver! (1968)
# 731     156     1953     5.0  French Connection, The (1971)
# 733     156     1956     5.0         Ordinary People (1980)
# 740     156     1965     5.0                Repo Man (1984)
# 741     156     1967     5.0               Labyrinth (1986)
# 753     156     2006     5.0      Mask of Zorro, The (1998)
# 681     156     1792     5.0           U.S. Marshals (1998)

# %%
predictions
# Out:
#       movieId                              title
# 531       920          Gone with the Wind (1939)
# 2338     4011                      Snatch (2000)
# 998      1721                     Titanic (1997)
# 533       924       2001: A Space Odyssey (1968)
# 86        151                     Rob Roy (1995)
# 1653     2872                   Excalibur (1981)
# 2548     4361                     Tootsie (1982)
# 1783     3100    River Runs Through It, A (1992)
# 2043     3524                      Arthur (1981)
# 783      1347  Nightmare on Elm Street, A (1984)
